# %% [markdown]
# #9.Code để thống kê và so sánh kết quả khi chạy 3 thuật toán BFS, IDDFS, A*

# %%
import pickle
import BFS
import A_search
import IDDFS
import matplotlib.pyplot as plt

# %%
# Load đồ thị
file_path = r"graph_with_attributes.pkl"
with open(file_path, "rb") as file:
    graph = pickle.load(file)

# Cố dịnh ending article
ending_article = "Minecraft"

#Đọc các starting articles từ file với UTF-8
with open("randomized_article_names.txt", "r", encoding="utf-8") as file:
    starting_articles = file.read().splitlines()

# %%
# Số lần chạy
num_runs = 100

# Thiết lập biến để đếm
bfs_path_exists_count = 0
astar_path_exists_count = 0
idfs_path_exists_count = 0
bfs_total_path_length = 0
astar_total_path_length = 0
idfs_total_path_length = 0
bfs_total_node_count = 0
astar_total_node_count = 0
idfs_total_node_count = 0
bfs_total_runtime = 0
idfs_total_runtime = 0
astar_total_runtime = 0
run_count = 0
valid_runs = 0

# %%
# Thực hiện các lần chạy
for starting_article in starting_articles:
    if run_count == num_runs:
        break

    run_count += 1
    print(run_count)
    # Thực hiênh BFS
    bfs_path_length, bfs_path, bfs_runtime, bfs_node_count = BFS.bfs_search(
        graph, starting_article, ending_article)
    if bfs_path_length is None:
        astar_path, astar_path_length, astar_runtime, astar_node_count = None, None, None, None
        idfs_path, idfs_path_length, idfs_runtime, idfs_node_count = None, None, None, None
        continue
    # Thực hiện A*
    astar_path, astar_node_count, astar_runtime, astar_path_length = A_search.astar(graph, starting_article,
                                                                                    ending_article)

    # Thực hiện IDDFS
    idfs_path, idfs_path_length, idfs_runtime, idfs_node_count = IDDFS.iddfs_search(graph, starting_article,
                                                                                    ending_article, 10)

    # Cập nhật các biến đếm
    if bfs_path_length is not None:
        valid_runs += 1
        bfs_path_exists_count += 1
        bfs_total_path_length += bfs_path_length
        bfs_total_runtime += bfs_runtime

    if astar_path_length is not None:
        astar_path_exists_count += 1
        astar_total_path_length += astar_path_length
        astar_total_runtime += astar_runtime

    if idfs_path_length is not None:
        idfs_path_exists_count += 1
        idfs_total_path_length += idfs_path_length
        idfs_total_runtime += idfs_runtime

    bfs_total_node_count += bfs_node_count
    astar_total_node_count += astar_node_count
    idfs_total_node_count += idfs_node_count

    # In kết quả
    print("--- Run", run_count, "with Starting Article:", starting_article, "---")
    print("--- BFS ---")
    if bfs_path_length is not None:
        print("Path Exists: Yes")
        print("Path:", bfs_path)
        print("Path Length:", bfs_path_length)
    else:
        print("Path Exists: No")
    print("Runtime:", bfs_runtime)
    print("Number of Nodes Visited:", bfs_node_count)

    print("--- A* ---")
    if astar_path_length is not None:
        print("Path Exists: Yes")
        print("Path:", astar_path)
        print("Path Length:", astar_path_length)
    else:
        print("Path Exists: No")
    print("Runtime:", astar_runtime)
    print("Number of Nodes Visited:", astar_node_count)

    print("--- IDFS ---")
    if idfs_path_length is not None:
        print("Path Exists: Yes")
        print("Path:", idfs_path)
        print("Path Length:", idfs_path_length)
    else:
        print("Path Exists: No")
    print("Runtime:", idfs_runtime)
    print("Number of Nodes Visited:", idfs_node_count)
    print("\n")
# Out:
# 1
# --- Run 1 with Starting Article: Okoboji, Iowa ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Okoboji, Iowa', 'United States', 'Activision Blizzard', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.8166332244873047
# Number of Nodes Visited: 17319
# --- A* ---
# Path Exists: Yes
# Path: ['Okoboji, Iowa', 'United States', 'Xbox Game Studios', 'Mojang Studios', 'Minecraft']
# Path Length: 5
# Runtime: 14.941294431686401
# Number of Nodes Visited: 206
# --- IDFS ---
# Path Exists: Yes
# Path: ['Okoboji, Iowa', 'United States', 'Activision Blizzard', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.03792309761047363
# Number of Nodes Visited: 3553
#
#
# 2
# --- Run 2 with Starting Article: Epic Games ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Epic Games', 'Gears of War', 'Microsoft', 'Minecraft']
# Path Length: 4
# Runtime: 0.01501917839050293
# Number of Nodes Visited: 1713
# --- A* ---
# Path Exists: Yes
# Path: ['Epic Games', 'Fortnite', 'Battle royale game', 'Minecraft']
# Path Length: 4
# Runtime: 0.12648797035217285
# Number of Nodes Visited: 4
# --- IDFS ---
# Path Exists: Yes
# Path: ['Epic Games', 'Gears of War', 'Microsoft', 'Minecraft']
# Path Length: 4
# Runtime: 0.0009987354278564453
# Number of Nodes Visited: 79
#
#
# 3
# --- Run 3 with Starting Article: Giovannino Guareschi ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Giovannino Guareschi', 'Italy', 'Mario Draghi', 'Mario', 'Minecraft']
# Path Length: 5
# Runtime: 0.09129667282104492
# Number of Nodes Visited: 9870
# --- A* ---
# Path Exists: Yes
# Path: ['Giovannino Guareschi', 'Italy', 'Mario Draghi', 'Mario', 'Minecraft']
# Path Length: 5
# Runtime: 6.042209625244141
# Number of Nodes Visited: 86
# --- IDFS ---
# Path Exists: Yes
# Path: ['Giovannino Guareschi', 'Italy', 'Mario Draghi', 'Mario', 'Minecraft']
# Path Length: 5
# Runtime: 0.009972095489501953
# Number of Nodes Visited: 616
#
#
# 4
# --- Run 4 with Starting Article: Bhopal district ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Bhopal district', 'India', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.15761065483093262
# Number of Nodes Visited: 20284
# --- A* ---
# Path Exists: Yes
# Path: ['Bhopal district', 'India', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 7.460949897766113
# Number of Nodes Visited: 112
# --- IDFS ---
# Path Exists: Yes
# Path: ['Bhopal district', 'India', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.048081398010253906
# Number of Nodes Visited: 4382
#
#
# 5
# --- Run 5 with Starting Article: Oleg Pavlov ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Oleg Pavlov', 'Russia', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.8900251388549805
# Number of Nodes Visited: 29482
# --- A* ---
# Path Exists: Yes
# Path: ['Oleg Pavlov', 'Moscow', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 8.074410915374756
# Number of Nodes Visited: 90
# --- IDFS ---
# Path Exists: Yes
# Path: ['Oleg Pavlov', 'Russia', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.08713102340698242
# Number of Nodes Visited: 6824
#
#
# 6
# --- Run 6 with Starting Article: Skibidi Toilet ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Skibidi Toilet', 'YouTube', 'MrBeast', 'Minecraft']
# Path Length: 4
# Runtime: 0.030426740646362305
# Number of Nodes Visited: 3680
# --- A* ---
# Path Exists: Yes
# Path: ['Skibidi Toilet', 'YouTube', 'PewDiePie', 'Minecraft']
# Path Length: 4
# Runtime: 1.0030865669250488
# Number of Nodes Visited: 9
# --- IDFS ---
# Path Exists: Yes
# Path: ['Skibidi Toilet', 'YouTube', 'MrBeast', 'Minecraft']
# Path Length: 4
# Runtime: 0.001994609832763672
# Number of Nodes Visited: 219
#
#
# 7
# --- Run 7 with Starting Article: 1830 United States census ---
# --- BFS ---
# Path Exists: Yes
# Path: ['1830 United States census', 'United States', 'Activision Blizzard', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.11121559143066406
# Number of Nodes Visited: 12031
# --- A* ---
# Path Exists: Yes
# Path: ['1830 United States census', 'United States', 'Activision Blizzard', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 9.366677045822144
# Number of Nodes Visited: 109
# --- IDFS ---
# Path Exists: Yes
# Path: ['1830 United States census', 'United States', 'Activision Blizzard', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.015046358108520508
# Number of Nodes Visited: 1010
#
#
# 8
# --- Run 8 with Starting Article: Bank of Israel ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Bank of Israel', 'Jerusalem', '20th century', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.8404455184936523
# Number of Nodes Visited: 25191
# --- A* ---
# Path Exists: Yes
# Path: ['Bank of Israel', 'Israel', '20th century', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 7.705206394195557
# Number of Nodes Visited: 99
# --- IDFS ---
# Path Exists: Yes
# Path: ['Bank of Israel', 'Jerusalem', '20th century', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.04790806770324707
# Number of Nodes Visited: 3236
#
#
# 9
# --- Run 9 with Starting Article: Ricardo (footballer, born 1977) ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Ricardo (footballer, born 1977)', '1977', '2011', 'Minecraft']
# Path Length: 4
# Runtime: 0.09334897994995117
# Number of Nodes Visited: 10234
# --- A* ---
# Path Exists: Yes
# Path: ['Ricardo (footballer, born 1977)', '1977', '2011', 'Minecraft']
# Path Length: 4
# Runtime: 2.1282076835632324
# Number of Nodes Visited: 4
# --- IDFS ---
# Path Exists: Yes
# Path: ['Ricardo (footballer, born 1977)', '1977', '2011', 'Minecraft']
# Path Length: 4
# Runtime: 0.006848335266113281
# Number of Nodes Visited: 286
#
#
# 10
# --- Run 10 with Starting Article: Councillor ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Councillor', 'United States', 'Activision Blizzard', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.8534588813781738
# Number of Nodes Visited: 37304
# --- A* ---
# Path Exists: Yes
# Path: ['Councillor', 'Northern Ireland', '1998', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 25.986999034881592
# Number of Nodes Visited: 487
# --- IDFS ---
# Path Exists: Yes
# Path: ['Councillor', 'United States', 'Activision Blizzard', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.1342325210571289
# Number of Nodes Visited: 9030
#
#
# 11
# --- Run 11 with Starting Article: Pineapple ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Pineapple', 'Mexico', '1910', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.23445415496826172
# Number of Nodes Visited: 42588
# --- A* ---
# Path Exists: Yes
# Path: ['Pineapple', 'Venezuela', 'July 24', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 3.7527055740356445
# Number of Nodes Visited: 14
# --- IDFS ---
# Path Exists: Yes
# Path: ['Pineapple', 'Mexico', '1910', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.09610581398010254
# Number of Nodes Visited: 5391
#
#
# 12
# --- Run 12 with Starting Article: Research ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Research', 'Charitable organization', 'Philanthropy', 'MrBeast', 'Minecraft']
# Path Length: 5
# Runtime: 0.0320127010345459
# Number of Nodes Visited: 3973
# --- A* ---
# Path Exists: Yes
# Path: ['Research', 'Institution', 'Harvard University', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 3.638253688812256
# Number of Nodes Visited: 52
# --- IDFS ---
# Path Exists: Yes
# Path: ['Research', 'Charitable organization', 'Philanthropy', 'MrBeast', 'Minecraft']
# Path Length: 5
# Runtime: 0.0039980411529541016
# Number of Nodes Visited: 238
#
#
# 13
# --- Run 13 with Starting Article: Cory Redding ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Cory Redding', 'Seattle Seahawks', 'Kingdome', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 1.4407312870025635
# Number of Nodes Visited: 36568
# --- A* ---
# Path Exists: Yes
# Path: ['Cory Redding', 'Seattle Seahawks', 'Kingdome', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 17.466941118240356
# Number of Nodes Visited: 124
# --- IDFS ---
# Path Exists: Yes
# Path: ['Cory Redding', 'Seattle Seahawks', 'Kingdome', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.12724709510803223
# Number of Nodes Visited: 7375
#
#
# 14
# --- Run 14 with Starting Article: Ribécourt-la-Tour ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Ribécourt-la-Tour', 'France', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.24193072319030762
# Number of Nodes Visited: 23824
# --- A* ---
# Path Exists: Yes
# Path: ['Ribécourt-la-Tour', 'France', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 3.3690311908721924
# Number of Nodes Visited: 15
# --- IDFS ---
# Path Exists: Yes
# Path: ['Ribécourt-la-Tour', 'France', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.03752946853637695
# Number of Nodes Visited: 3069
#
#
# 15
# --- Run 15 with Starting Article: Lake County, Oregon ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Lake County, Oregon', 'County (United States)', 'Los Angeles County, California', 'Activision Blizzard', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 1.1322200298309326
# Number of Nodes Visited: 52896
# --- A* ---
# Path Exists: Yes
# Path: ['Lake County, Oregon', 'Oregon', 'United States', 'Activision Blizzard', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 19.88058590888977
# Number of Nodes Visited: 258
# --- IDFS ---
# Path Exists: Yes
# Path: ['Lake County, Oregon', 'County (United States)', 'Los Angeles County, California', 'Activision Blizzard', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 0.4587843418121338
# Number of Nodes Visited: 26577
#
#
# 16
# --- Run 16 with Starting Article: Tonny Bruins Slot ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Tonny Bruins Slot', 'Netherlands', 'Fourth Rutte cabinet', '2022', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 0.36427879333496094
# Number of Nodes Visited: 65547
# --- A* ---
# Path Exists: Yes
# Path: ['Tonny Bruins Slot', 'PSV Eindhoven', 'Chelsea F.C.', '2006', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 21.50005865097046
# Number of Nodes Visited: 363
# --- IDFS ---
# Path Exists: Yes
# Path: ['Tonny Bruins Slot', 'Netherlands', 'Fourth Rutte cabinet', '2022', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 0.5161848068237305
# Number of Nodes Visited: 35073
#
#
# 17
# --- Run 17 with Starting Article: Survivor: Africa ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Survivor: Africa', 'Africa', '20th century', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 1.0803992748260498
# Number of Nodes Visited: 39031
# --- A* ---
# Path Exists: Yes
# Path: ['Survivor: Africa', 'Cambridge, Massachusetts', 'Harvard University', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 13.587289094924927
# Number of Nodes Visited: 214
# --- IDFS ---
# Path Exists: Yes
# Path: ['Survivor: Africa', 'Africa', '20th century', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.16401100158691406
# Number of Nodes Visited: 9014
#
#
# 18
# --- Run 18 with Starting Article: Sugako Hashida ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Sugako Hashida', 'Korea under Japanese rule', '1945', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.29499316215515137
# Number of Nodes Visited: 26050
# --- A* ---
# Path Exists: Yes
# Path: ['Sugako Hashida', 'Waseda University', 'Shinichi Oishi', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 5.528813123703003
# Number of Nodes Visited: 61
# --- IDFS ---
# Path Exists: Yes
# Path: ['Sugako Hashida', 'Korea under Japanese rule', '1945', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.047029972076416016
# Number of Nodes Visited: 3509
#
#
# 19
# --- Run 19 with Starting Article: Bergman, Arkansas ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Bergman, Arkansas', '2020 United States Census', 'Connecticut', 'Mohegan', 'Wolf', 'Minecraft']
# Path Length: 6
# Runtime: 0.935835599899292
# Number of Nodes Visited: 42494
# --- A* ---
# Path Exists: Yes
# Path: ['Bergman, Arkansas', '2020 United States Census', 'Donald Trump', 'MSN', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 14.795692920684814
# Number of Nodes Visited: 253
# --- IDFS ---
# Path Exists: Yes
# Path: ['Bergman, Arkansas', '2020 United States Census', 'Connecticut', 'Mohegan', 'Wolf', 'Minecraft']
# Path Length: 6
# Runtime: 0.2520601749420166
# Number of Nodes Visited: 17433
#
#
# 20
# --- Run 20 with Starting Article: Le Brusquet ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Le Brusquet', 'Departments of France', 'Guéret', 'Wolf', 'Minecraft']
# Path Length: 5
# Runtime: 0.14601707458496094
# Number of Nodes Visited: 20065
# --- A* ---
# Path Exists: Yes
# Path: ['Le Brusquet', 'France', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 10.823139190673828
# Number of Nodes Visited: 208
# --- IDFS ---
# Path Exists: Yes
# Path: ['Le Brusquet', 'Departments of France', 'Guéret', 'Wolf', 'Minecraft']
# Path Length: 5
# Runtime: 0.04488205909729004
# Number of Nodes Visited: 3324
#
#
# 21
# --- Run 21 with Starting Article: Ommen ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Ommen', 'Salland', 'Franks', 'January 28', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.2481398582458496
# Number of Nodes Visited: 47311
# --- A* ---
# Path Exists: Yes
# Path: ['Ommen', 'Netherlands', 'Poland', 'Earth', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 17.909358024597168
# Number of Nodes Visited: 330
# --- IDFS ---
# Path Exists: Yes
# Path: ['Ommen', 'Salland', 'Franks', 'January 28', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.5465297698974609
# Number of Nodes Visited: 38664
#
#
# 22
# --- Run 22 with Starting Article: Ichi the Killer ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Ichi the Killer', 'Japan', 'Nintendo', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.9407074451446533
# Number of Nodes Visited: 28531
# --- A* ---
# Path Exists: Yes
# Path: ['Ichi the Killer', 'Japan', 'Nintendo', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 10.042928218841553
# Number of Nodes Visited: 128
# --- IDFS ---
# Path Exists: Yes
# Path: ['Ichi the Killer', 'Japan', 'Nintendo', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.05188941955566406
# Number of Nodes Visited: 3632
#
#
# 23
# --- Run 23 with Starting Article: Passenger pigeon ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Passenger pigeon', 'North America', 'Earth', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.1518387794494629
# Number of Nodes Visited: 15491
# --- A* ---
# Path Exists: Yes
# Path: ['Passenger pigeon', 'North America', 'Earth', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 3.4293248653411865
# Number of Nodes Visited: 53
# --- IDFS ---
# Path Exists: Yes
# Path: ['Passenger pigeon', 'North America', 'Earth', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.02567601203918457
# Number of Nodes Visited: 2061
#
#
# 24
# --- Run 24 with Starting Article: Australian Music Online ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Australian Music Online', '2007', 'Microsoft', 'Minecraft']
# Path Length: 4
# Runtime: 0.9021046161651611
# Number of Nodes Visited: 18571
# --- A* ---
# Path Exists: Yes
# Path: ['Australian Music Online', '2007', 'Microsoft', 'Minecraft']
# Path Length: 4
# Runtime: 3.2624518871307373
# Number of Nodes Visited: 6
# --- IDFS ---
# Path Exists: Yes
# Path: ['Australian Music Online', '2007', 'Microsoft', 'Minecraft']
# Path Length: 4
# Runtime: 0.01800990104675293
# Number of Nodes Visited: 282
#
#
# 25
# --- Run 25 with Starting Article: Walter Bernstein ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Walter Bernstein', 'Hollywood', 'Earth', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.31798481941223145
# Number of Nodes Visited: 58594
# --- A* ---
# Path Exists: Yes
# Path: ['Walter Bernstein', 'Hollywood', 'Earth', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 6.307150840759277
# Number of Nodes Visited: 66
# --- IDFS ---
# Path Exists: Yes
# Path: ['Walter Bernstein', 'Hollywood', 'Earth', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.21064257621765137
# Number of Nodes Visited: 14970
#
#
# 26
# --- Run 26 with Starting Article: Heavy Rain ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Heavy Rain', 'Microsoft Windows', 'Microsoft', 'Minecraft']
# Path Length: 4
# Runtime: 0.018653392791748047
# Number of Nodes Visited: 2067
# --- A* ---
# Path Exists: Yes
# Path: ['Heavy Rain', 'PlayStation 3', 'Microsoft', 'Minecraft']
# Path Length: 4
# Runtime: 0.26285600662231445
# Number of Nodes Visited: 6
# --- IDFS ---
# Path Exists: Yes
# Path: ['Heavy Rain', 'Microsoft Windows', 'Microsoft', 'Minecraft']
# Path Length: 4
# Runtime: 0.000997781753540039
# Number of Nodes Visited: 159
#
#
# 27
# --- Run 27 with Starting Article: Al-Khwarizmi ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Al-Khwarizmi', 'Persian people', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.7603251934051514
# Number of Nodes Visited: 13306
# --- A* ---
# Path Exists: Yes
# Path: ['Al-Khwarizmi', 'Persian people', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 1.9785101413726807
# Number of Nodes Visited: 34
# --- IDFS ---
# Path Exists: Yes
# Path: ['Al-Khwarizmi', 'Persian people', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.015906333923339844
# Number of Nodes Visited: 1267
#
#
# 28
# --- Run 28 with Starting Article: Brummen ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Brummen', 'Provinces of the Netherlands', 'January 1', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.20577049255371094
# Number of Nodes Visited: 41494
# --- A* ---
# Path Exists: Yes
# Path: ['Brummen', 'Provinces of the Netherlands', 'January 1', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 7.504533290863037
# Number of Nodes Visited: 72
# --- IDFS ---
# Path Exists: Yes
# Path: ['Brummen', 'Provinces of the Netherlands', 'January 1', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.07933664321899414
# Number of Nodes Visited: 3813
#
#
# 29
# --- Run 29 with Starting Article: Zezé Procópio ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Zezé Procópio', 'Brazil', 'Earth', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.12724924087524414
# Number of Nodes Visited: 18375
# --- A* ---
# Path Exists: Yes
# Path: ['Zezé Procópio', 'São Paulo F.C.', 'December 16', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 3.391763210296631
# Number of Nodes Visited: 22
# --- IDFS ---
# Path Exists: Yes
# Path: ['Zezé Procópio', 'Brazil', 'Earth', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.02451300621032715
# Number of Nodes Visited: 1946
#
#
# 30
# --- Run 30 with Starting Article: U.S. Route 250 ---
# --- BFS ---
# Path Exists: Yes
# Path: ['U.S. Route 250', 'West Virginia', 'American black bear', 'Wolf', 'Minecraft']
# Path Length: 5
# Runtime: 0.8166532516479492
# Number of Nodes Visited: 24518
# --- A* ---
# Path Exists: Yes
# Path: ['U.S. Route 250', 'Wooster, Ohio', 'United States', 'Activision Blizzard', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 14.651881456375122
# Number of Nodes Visited: 501
# --- IDFS ---
# Path Exists: Yes
# Path: ['U.S. Route 250', 'West Virginia', 'American black bear', 'Wolf', 'Minecraft']
# Path Length: 5
# Runtime: 0.10979986190795898
# Number of Nodes Visited: 8777
#
#
# 31
# --- Run 31 with Starting Article: The Texas Chainsaw Massacre (franchise) ---
# --- BFS ---
# Path Exists: Yes
# Path: ['The Texas Chainsaw Massacre (franchise)', 'Internet Movie Database', '1998', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.1731400489807129
# Number of Nodes Visited: 24279
# --- A* ---
# Path Exists: Yes
# Path: ['The Texas Chainsaw Massacre (franchise)', 'Internet Movie Database', '1998', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 2.4277474880218506
# Number of Nodes Visited: 7
# --- IDFS ---
# Path Exists: Yes
# Path: ['The Texas Chainsaw Massacre (franchise)', 'Internet Movie Database', '1998', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.01564621925354004
# Number of Nodes Visited: 614
#
#
# 32
# --- Run 32 with Starting Article: Tsūtenkaku ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Tsūtenkaku', 'Osaka', '1980', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.8971102237701416
# Number of Nodes Visited: 39941
# --- A* ---
# Path Exists: Yes
# Path: ['Tsūtenkaku', 'Japan', 'Nintendo', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.7848062515258789
# Number of Nodes Visited: 10
# --- IDFS ---
# Path Exists: Yes
# Path: ['Tsūtenkaku', 'Osaka', '1980', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.06298565864562988
# Number of Nodes Visited: 1727
#
#
# 33
# --- Run 33 with Starting Article: FC Valdagno ---
# --- BFS ---
# Path Exists: Yes
# Path: ['FC Valdagno', 'Italy', 'Mario Draghi', 'Mario', 'Minecraft']
# Path Length: 5
# Runtime: 0.0941169261932373
# Number of Nodes Visited: 10741
# --- A* ---
# Path Exists: Yes
# Path: ['FC Valdagno', 'Italy', 'Mario Draghi', 'Mario', 'Minecraft']
# Path Length: 5
# Runtime: 6.077600955963135
# Number of Nodes Visited: 112
# --- IDFS ---
# Path Exists: Yes
# Path: ['FC Valdagno', 'Italy', 'Mario Draghi', 'Mario', 'Minecraft']
# Path Length: 5
# Runtime: 0.016042232513427734
# Number of Nodes Visited: 688
#
#
# 34
# --- Run 34 with Starting Article: Deaths in April 2022 ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Deaths in April 2022', 'April 14', '2011', 'Minecraft']
# Path Length: 4
# Runtime: 0.15674161911010742
# Number of Nodes Visited: 21277
# --- A* ---
# Path Exists: Yes
# Path: ['Deaths in April 2022', 'April 27', '2011', 'Minecraft']
# Path Length: 4
# Runtime: 3.319699287414551
# Number of Nodes Visited: 6
# --- IDFS ---
# Path Exists: Yes
# Path: ['Deaths in April 2022', 'April 14', '2011', 'Minecraft']
# Path Length: 4
# Runtime: 0.016065359115600586
# Number of Nodes Visited: 808
#
#
# 35
# --- Run 35 with Starting Article: Wasserburg am Inn ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Wasserburg am Inn', 'Upper Bavaria', 'Munich', 'Munich U-Bahn', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.7907476425170898
# Number of Nodes Visited: 17560
# --- A* ---
# Path Exists: Yes
# Path: ['Wasserburg am Inn', 'Central Bavarian', 'Salzburg', '1927', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 13.398597955703735
# Number of Nodes Visited: 219
# --- IDFS ---
# Path Exists: Yes
# Path: ['Wasserburg am Inn', 'Upper Bavaria', 'Munich', 'Munich U-Bahn', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.0473942756652832
# Number of Nodes Visited: 2957
#
#
# 36
# --- Run 36 with Starting Article: Machair (TV series) ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Machair (TV series)', 'English language', 'Singapore', 'December', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.2518582344055176
# Number of Nodes Visited: 57038
# --- A* ---
# Path Exists: Yes
# Path: ['Machair (TV series)', 'Scotland', 'Gretna F.C.', 'June 3', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 21.436688661575317
# Number of Nodes Visited: 374
# --- IDFS ---
# Path Exists: Yes
# Path: ['Machair (TV series)', 'English language', 'Singapore', 'December', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.33138489723205566
# Number of Nodes Visited: 21307
#
#
# 37
# --- Run 37 with Starting Article: Oppy, Pas-de-Calais ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Oppy, Pas-de-Calais', 'Departments of France', 'Guéret', 'Wolf', 'Minecraft']
# Path Length: 5
# Runtime: 0.8152344226837158
# Number of Nodes Visited: 20002
# --- A* ---
# Path Exists: Yes
# Path: ['Oppy, Pas-de-Calais', 'Departments of France', 'Guéret', 'Wolf', 'Minecraft']
# Path Length: 5
# Runtime: 4.483472108840942
# Number of Nodes Visited: 117
# --- IDFS ---
# Path Exists: Yes
# Path: ['Oppy, Pas-de-Calais', 'Departments of France', 'Guéret', 'Wolf', 'Minecraft']
# Path Length: 5
# Runtime: 0.04294157028198242
# Number of Nodes Visited: 3395
#
#
# 38
# --- Run 38 with Starting Article: Constitution of India ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Constitution of India', 'India', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.18262410163879395
# Number of Nodes Visited: 31287
# --- A* ---
# Path Exists: Yes
# Path: ['Constitution of India', 'India', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 9.774717092514038
# Number of Nodes Visited: 262
# --- IDFS ---
# Path Exists: Yes
# Path: ['Constitution of India', 'India', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.10928893089294434
# Number of Nodes Visited: 10141
#
#
# 39
# --- Run 39 with Starting Article: Electorate of Bavaria ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Electorate of Bavaria', 'Munich', 'Munich U-Bahn', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.8425917625427246
# Number of Nodes Visited: 21235
# --- A* ---
# Path Exists: Yes
# Path: ['Electorate of Bavaria', 'Personal union', '1941', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 2.9897119998931885
# Number of Nodes Visited: 13
# --- IDFS ---
# Path Exists: Yes
# Path: ['Electorate of Bavaria', 'Munich', 'Munich U-Bahn', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.03246307373046875
# Number of Nodes Visited: 2424
#
#
# 40
# --- Run 40 with Starting Article: Leonardtown, Maryland ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Leonardtown, Maryland', 'United States', 'Activision Blizzard', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.16341924667358398
# Number of Nodes Visited: 18143
# --- A* ---
# Path Exists: Yes
# Path: ['Leonardtown, Maryland', 'United States', 'Xbox Game Studios', 'Mojang Studios', 'Minecraft']
# Path Length: 5
# Runtime: 12.21252179145813
# Number of Nodes Visited: 198
# --- IDFS ---
# Path Exists: Yes
# Path: ['Leonardtown, Maryland', 'United States', 'Activision Blizzard', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.03345465660095215
# Number of Nodes Visited: 2514
#
#
# 41
# --- Run 41 with Starting Article: Villy-en-Trodes ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Villy-en-Trodes', 'France', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.8128960132598877
# Number of Nodes Visited: 24353
# --- A* ---
# Path Exists: Yes
# Path: ['Villy-en-Trodes', 'France', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 10.880653619766235
# Number of Nodes Visited: 135
# --- IDFS ---
# Path Exists: Yes
# Path: ['Villy-en-Trodes', 'France', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.04023885726928711
# Number of Nodes Visited: 3130
#
#
# 42
# --- Run 42 with Starting Article: Litoria chrisdahli ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Litoria chrisdahli', 'Papua New Guinea', 'Unitary state', 'Greece', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.2997889518737793
# Number of Nodes Visited: 46990
# --- A* ---
# Path Exists: Yes
# Path: ['Litoria chrisdahli', 'Papua New Guinea', 'Charles III', 'September 8', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 5.106150150299072
# Number of Nodes Visited: 36
# --- IDFS ---
# Path Exists: Yes
# Path: ['Litoria chrisdahli', 'Papua New Guinea', 'Unitary state', 'Greece', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.19024109840393066
# Number of Nodes Visited: 12093
#
#
# 43
# --- Run 43 with Starting Article: Funnel cloud ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Funnel cloud', 'Texas', 'Technology company', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.1799309253692627
# Number of Nodes Visited: 20457
# --- A* ---
# Path Exists: Yes
# Path: ['Funnel cloud', 'Texas', 'Technology company', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 1.0984735488891602
# Number of Nodes Visited: 17
# --- IDFS ---
# Path Exists: Yes
# Path: ['Funnel cloud', 'Texas', 'Technology company', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.03282809257507324
# Number of Nodes Visited: 2566
#
#
# 44
# --- Run 44 with Starting Article: Don Shepherd ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Don Shepherd', 'Test cricket', 'England', 'UEFA Euro 2012', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.9672529697418213
# Number of Nodes Visited: 38309
# --- A* ---
# Path Exists: Yes
# Path: ['Don Shepherd', 'Test cricket', 'India', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 14.161956310272217
# Number of Nodes Visited: 227
# --- IDFS ---
# Path Exists: Yes
# Path: ['Don Shepherd', 'Test cricket', 'England', 'UEFA Euro 2012', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.16356921195983887
# Number of Nodes Visited: 10110
#
#
# 45
# --- Run 45 with Starting Article: Pop art ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Pop art', 'Larry Rivers', 'Poet', 'Greece', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.38048505783081055
# Number of Nodes Visited: 58747
# --- A* ---
# Path Exists: Yes
# Path: ['Pop art', 'London', '1908', 'August 27', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 21.746732234954834
# Number of Nodes Visited: 281
# --- IDFS ---
# Path Exists: Yes
# Path: ['Pop art', 'Larry Rivers', 'Poet', 'Greece', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.2573409080505371
# Number of Nodes Visited: 16884
#
#
# 46
# --- Run 46 with Starting Article: Wilhelm Ostwald ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Wilhelm Ostwald', '1909', '2011', 'Minecraft']
# Path Length: 4
# Runtime: 0.7797553539276123
# Number of Nodes Visited: 6727
# --- A* ---
# Path Exists: Yes
# Path: ['Wilhelm Ostwald', '1909', '2011', 'Minecraft']
# Path Length: 4
# Runtime: 2.497225522994995
# Number of Nodes Visited: 10
# --- IDFS ---
# Path Exists: Yes
# Path: ['Wilhelm Ostwald', '1909', '2011', 'Minecraft']
# Path Length: 4
# Runtime: 0.006224155426025391
# Number of Nodes Visited: 189
#
#
# 47
# --- Run 47 with Starting Article: Douglas Mawson ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Douglas Mawson', 'Antarctic', 'Earth', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.26269078254699707
# Number of Nodes Visited: 17400
# --- A* ---
# Path Exists: Yes
# Path: ['Douglas Mawson', 'Australia', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 10.914643287658691
# Number of Nodes Visited: 164
# --- IDFS ---
# Path Exists: Yes
# Path: ['Douglas Mawson', 'Antarctic', 'Earth', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.03606557846069336
# Number of Nodes Visited: 3004
#
#
# 48
# --- Run 48 with Starting Article: Alcester Grammar School ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Alcester Grammar School', 'England', 'UEFA Euro 2012', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.9265608787536621
# Number of Nodes Visited: 34087
# --- A* ---
# Path Exists: Yes
# Path: ['Alcester Grammar School', 'Warwickshire', '1931', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 7.613024473190308
# Number of Nodes Visited: 75
# --- IDFS ---
# Path Exists: Yes
# Path: ['Alcester Grammar School', 'England', 'UEFA Euro 2012', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.08234190940856934
# Number of Nodes Visited: 6153
#
#
# 49
# --- Run 49 with Starting Article: Frederick F. Woerner Jr. ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Frederick F. Woerner Jr.', 'Vietnam War', 'Ho Chi Minh', 'May 19', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.30031275749206543
# Number of Nodes Visited: 57741
# --- A* ---
# Path Exists: Yes
# Path: ['Frederick F. Woerner Jr.', 'Vietnam War', 'Thailand', 'September 19', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 20.85519814491272
# Number of Nodes Visited: 297
# --- IDFS ---
# Path Exists: Yes
# Path: ['Frederick F. Woerner Jr.', 'Vietnam War', 'Ho Chi Minh', 'May 19', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.2709789276123047
# Number of Nodes Visited: 18110
#
#
# 50
# --- Run 50 with Starting Article: Queen Latifah ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Queen Latifah', 'Dance music', '20th century', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 1.0165424346923828
# Number of Nodes Visited: 34478
# --- A* ---
# Path Exists: Yes
# Path: ['Queen Latifah', 'Dance music', '20th century', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 26.2385892868042
# Number of Nodes Visited: 312
# --- IDFS ---
# Path Exists: Yes
# Path: ['Queen Latifah', 'Dance music', '20th century', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.10904979705810547
# Number of Nodes Visited: 5677
#
#
# 51
# --- Run 51 with Starting Article: Chi McBride ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Chi McBride', 'The Terminal', 'Steven Spielberg', '1998', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.3601200580596924
# Number of Nodes Visited: 49817
# --- A* ---
# Path Exists: Yes
# Path: ['Chi McBride', 'Roll Bounce', 'United States', 'Xbox Game Studios', 'Mojang Studios', 'Minecraft']
# Path Length: 6
# Runtime: 4.23577356338501
# Number of Nodes Visited: 29
# --- IDFS ---
# Path Exists: Yes
# Path: ['Chi McBride', 'The Terminal', 'Steven Spielberg', '1998', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.1411435604095459
# Number of Nodes Visited: 6707
#
#
# 52
# --- Run 52 with Starting Article: Carl Ruiz ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Carl Ruiz', 'Maryland', 'Massachusetts', 'Harvard University', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 1.0070466995239258
# Number of Nodes Visited: 40150
# --- A* ---
# Path Exists: Yes
# Path: ['Carl Ruiz', 'Americans', 'Spanish language', 'December', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 14.920981645584106
# Number of Nodes Visited: 113
# --- IDFS ---
# Path Exists: Yes
# Path: ['Carl Ruiz', 'Maryland', 'Massachusetts', 'Harvard University', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 0.1386432647705078
# Number of Nodes Visited: 10572
#
#
# 53
# --- Run 53 with Starting Article: Call of Duty: Modern Warfare ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Call of Duty: Modern Warfare', 'Call of Duty: Modern Warfare 3', 'Microsoft Windows', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.05539822578430176
# Number of Nodes Visited: 3053
# --- A* ---
# Path Exists: Yes
# Path: ['Call of Duty: Modern Warfare', 'Call of Duty: Modern Warfare 3', 'YouTube', 'PewDiePie', 'Minecraft']
# Path Length: 5
# Runtime: 2.2632205486297607
# Number of Nodes Visited: 14
# --- IDFS ---
# Path Exists: Yes
# Path: ['Call of Duty: Modern Warfare', 'Call of Duty: Modern Warfare 3', 'Microsoft Windows', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.0019953250885009766
# Number of Nodes Visited: 144
#
#
# 54
# --- Run 54 with Starting Article: Allergy ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Allergy', 'Tobacco', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.16014862060546875
# Number of Nodes Visited: 19055
# --- A* ---
# Path Exists: Yes
# Path: ['Allergy', 'Tobacco', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 3.0528547763824463
# Number of Nodes Visited: 16
# --- IDFS ---
# Path Exists: Yes
# Path: ['Allergy', 'Tobacco', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.019107341766357422
# Number of Nodes Visited: 2100
#
#
# 55
# --- Run 55 with Starting Article: Primatomorpha ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Primatomorpha', 'Rodent', 'Rabbit', 'Wolf', 'Minecraft']
# Path Length: 5
# Runtime: 0.10668039321899414
# Number of Nodes Visited: 11235
# --- A* ---
# Path Exists: Yes
# Path: ['Primatomorpha', 'Rodent', 'Rabbit', 'Wolf', 'Minecraft']
# Path Length: 5
# Runtime: 3.7677083015441895
# Number of Nodes Visited: 80
# --- IDFS ---
# Path Exists: Yes
# Path: ['Primatomorpha', 'Rodent', 'Rabbit', 'Wolf', 'Minecraft']
# Path Length: 5
# Runtime: 0.03163409233093262
# Number of Nodes Visited: 2061
#
#
# 56
# --- Run 56 with Starting Article: Royal Commission ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Royal Commission', 'Australia', 'Royal Australian Navy', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.9427080154418945
# Number of Nodes Visited: 49750
# --- A* ---
# Path Exists: Yes
# Path: ['Royal Commission', 'Australia', 'Royal Australian Navy', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 11.508949518203735
# Number of Nodes Visited: 160
# --- IDFS ---
# Path Exists: Yes
# Path: ['Royal Commission', 'Australia', 'Royal Australian Navy', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.35309886932373047
# Number of Nodes Visited: 25494
#
#
# 57
# --- Run 57 with Starting Article: Kebakalan ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Kebakalan', 'Indonesia', 'Singapore', 'December', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.24852418899536133
# Number of Nodes Visited: 45004
# --- A* ---
# Path Exists: Yes
# Path: ['Kebakalan', 'Indonesia', 'Mexico', '1940', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 9.197478294372559
# Number of Nodes Visited: 112
# --- IDFS ---
# Path Exists: Yes
# Path: ['Kebakalan', 'Indonesia', 'Singapore', 'December', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.16458559036254883
# Number of Nodes Visited: 10335
#
#
# 58
# --- Run 58 with Starting Article: The Faint ---
# --- BFS ---
# Path Exists: Yes
# Path: ['The Faint', 'United States', 'Activision Blizzard', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.8595139980316162
# Number of Nodes Visited: 18047
# --- A* ---
# Path Exists: Yes
# Path: ['The Faint', 'United States', 'Activision Blizzard', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 8.293069124221802
# Number of Nodes Visited: 107
# --- IDFS ---
# Path Exists: Yes
# Path: ['The Faint', 'United States', 'Activision Blizzard', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.031004905700683594
# Number of Nodes Visited: 2483
#
#
# 59
# --- Run 59 with Starting Article: Outeniqua Mountains ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Outeniqua Mountains', 'Western Cape', 'Atlantic Ocean', 'Earth', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 0.16410064697265625
# Number of Nodes Visited: 26588
# --- A* ---
# Path Exists: Yes
# Path: ['Outeniqua Mountains', 'South Africa', 'Gujarati language', 'Microsoft Word', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 11.62099289894104
# Number of Nodes Visited: 307
# --- IDFS ---
# Path Exists: Yes
# Path: ['Outeniqua Mountains', 'Western Cape', 'Atlantic Ocean', 'Earth', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 0.07282781600952148
# Number of Nodes Visited: 5644
#
#
# 60
# --- Run 60 with Starting Article: Roman Catholic Diocese of Calgary ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Roman Catholic Diocese of Calgary', 'Canada', 'Saint Lawrence Seaway', '20th century', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.9540152549743652
# Number of Nodes Visited: 57335
# --- A* ---
# Path Exists: Yes
# Path: ['Roman Catholic Diocese of Calgary', 'Canada', 'Saint Lawrence Seaway', '20th century', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 23.957587718963623
# Number of Nodes Visited: 714
# --- IDFS ---
# Path Exists: Yes
# Path: ['Roman Catholic Diocese of Calgary', 'Canada', 'Saint Lawrence Seaway', '20th century', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.32514023780822754
# Number of Nodes Visited: 23163
#
#
# 61
# --- Run 61 with Starting Article: The Valley, Anguilla ---
# --- BFS ---
# Path Exists: Yes
# Path: ['The Valley, Anguilla', 'Anguilla', 'British Overseas Territories', '2006', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.267289400100708
# Number of Nodes Visited: 53162
# --- A* ---
# Path Exists: Yes
# Path: ['The Valley, Anguilla', 'Anguilla', 'Monarchy of the United Kingdom', '1952', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 11.532325029373169
# Number of Nodes Visited: 201
# --- IDFS ---
# Path Exists: Yes
# Path: ['The Valley, Anguilla', 'Anguilla', 'British Overseas Territories', '2006', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.2653975486755371
# Number of Nodes Visited: 7868
#
#
# 62
# --- Run 62 with Starting Article: Rous Cup ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Rous Cup', 'England national football team', 'Belfast', '1921', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.818650484085083
# Number of Nodes Visited: 17947
# --- A* ---
# Path Exists: Yes
# Path: ['Rous Cup', 'England national football team', 'Wembley Stadium (1923)', '1985', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 13.85649561882019
# Number of Nodes Visited: 375
# --- IDFS ---
# Path Exists: Yes
# Path: ['Rous Cup', 'England national football team', 'Belfast', '1921', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.024844884872436523
# Number of Nodes Visited: 1531
#
#
# 63
# --- Run 63 with Starting Article: Héricourt (Haute-Saône) ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Héricourt (Haute-Saône)', 'Departments of France', 'Guéret', 'Wolf', 'Minecraft']
# Path Length: 5
# Runtime: 0.15417885780334473
# Number of Nodes Visited: 24940
# --- A* ---
# Path Exists: Yes
# Path: ['Héricourt (Haute-Saône)', 'France', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 9.140333414077759
# Number of Nodes Visited: 145
# --- IDFS ---
# Path Exists: Yes
# Path: ['Héricourt (Haute-Saône)', 'Departments of France', 'Guéret', 'Wolf', 'Minecraft']
# Path Length: 5
# Runtime: 0.07734942436218262
# Number of Nodes Visited: 5433
#
#
# 64
# --- Run 64 with Starting Article: It's the End of the World as We Know It (And I Feel Fine) ---
# --- BFS ---
# Path Exists: Yes
# Path: ["It's the End of the World as We Know It (And I Feel Fine)", 'Alternative rock', '1990s', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.9388136863708496
# Number of Nodes Visited: 37798
# --- A* ---
# Path Exists: Yes
# Path: ["It's the End of the World as We Know It (And I Feel Fine)", 'Alternative rock', '1990s', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 2.2468342781066895
# Number of Nodes Visited: 51
# --- IDFS ---
# Path Exists: Yes
# Path: ["It's the End of the World as We Know It (And I Feel Fine)", 'Alternative rock', '1990s', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.06151461601257324
# Number of Nodes Visited: 3189
#
#
# 65
# --- Run 65 with Starting Article: Lynching postcard ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Lynching postcard', 'United States', 'Activision Blizzard', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.13074851036071777
# Number of Nodes Visited: 16488
# --- A* ---
# Path Exists: Yes
# Path: ['Lynching postcard', 'Oklahoma', '20th century', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 5.0135767459869385
# Number of Nodes Visited: 16
# --- IDFS ---
# Path Exists: Yes
# Path: ['Lynching postcard', 'United States', 'Activision Blizzard', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.03127908706665039
# Number of Nodes Visited: 2010
#
#
# 66
# --- Run 66 with Starting Article: Canberra ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Canberra', 'Berlin', '2006', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.9592335224151611
# Number of Nodes Visited: 50562
# --- A* ---
# Path Exists: Yes
# Path: ['Canberra', 'Berlin', '1945', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 5.533230543136597
# Number of Nodes Visited: 33
# --- IDFS ---
# Path Exists: Yes
# Path: ['Canberra', 'Berlin', '2006', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.1281726360321045
# Number of Nodes Visited: 6088
#
#
# 67
# --- Run 67 with Starting Article: Very important person ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Very important person', 'White émigré', 'Finland', 'Nokia, Finland', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 0.22269535064697266
# Number of Nodes Visited: 35061
# --- A* ---
# Path Exists: Yes
# Path: ['Very important person', 'White émigré', 'Christianity', '20th century', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 12.557080268859863
# Number of Nodes Visited: 78
# --- IDFS ---
# Path Exists: Yes
# Path: ['Very important person', 'White émigré', 'Finland', 'Nokia, Finland', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 0.09879469871520996
# Number of Nodes Visited: 7429
#
#
# 68
# --- Run 68 with Starting Article: Lucy Joan Slater ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Lucy Joan Slater', 'Cambridge University Press', 'University of Cambridge', 'Bill Gates', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 0.2891247272491455
# Number of Nodes Visited: 55267
# --- A* ---
# Path Exists: Yes
# Path: ['Lucy Joan Slater', 'Fortran', '1997', '1921', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 7.241326808929443
# Number of Nodes Visited: 49
# --- IDFS ---
# Path Exists: Yes
# Path: ['Lucy Joan Slater', 'Cambridge University Press', 'University of Cambridge', 'Bill Gates', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 0.21126890182495117
# Number of Nodes Visited: 9139
#
#
# 69
# --- Run 69 with Starting Article: Sebastián Rulli ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Sebastián Rulli', 'Buenos Aires', '2009', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.1720728874206543
# Number of Nodes Visited: 28919
# --- A* ---
# Path Exists: Yes
# Path: ['Sebastián Rulli', 'Buenos Aires', '2009', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 1.5397260189056396
# Number of Nodes Visited: 21
# --- IDFS ---
# Path Exists: Yes
# Path: ['Sebastián Rulli', 'Buenos Aires', '2009', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.06283354759216309
# Number of Nodes Visited: 3152
#
#
# 70
# --- Run 70 with Starting Article: Soupex ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Soupex', 'Departments of France', 'Guéret', 'Wolf', 'Minecraft']
# Path Length: 5
# Runtime: 0.15380096435546875
# Number of Nodes Visited: 20452
# --- A* ---
# Path Exists: Yes
# Path: ['Soupex', 'France', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 4.838866710662842
# Number of Nodes Visited: 23
# --- IDFS ---
# Path Exists: Yes
# Path: ['Soupex', 'Departments of France', 'Guéret', 'Wolf', 'Minecraft']
# Path Length: 5
# Runtime: 0.04549407958984375
# Number of Nodes Visited: 3469
#
#
# 71
# --- Run 71 with Starting Article: Deal barracks bombing ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Deal barracks bombing', 'Kent', '1990s', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 1.0490601062774658
# Number of Nodes Visited: 10925
# --- A* ---
# Path Exists: Yes
# Path: ['Deal barracks bombing', 'England', 'UEFA Euro 2012', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 7.529234409332275
# Number of Nodes Visited: 84
# --- IDFS ---
# Path Exists: Yes
# Path: ['Deal barracks bombing', 'Kent', '1990s', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.012967109680175781
# Number of Nodes Visited: 863
#
#
# 72
# --- Run 72 with Starting Article: Itawamba County, Mississippi ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Itawamba County, Mississippi', 'County (United States)', 'Los Angeles County, California', 'Activision Blizzard', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 0.2628931999206543
# Number of Nodes Visited: 52953
# --- A* ---
# Path Exists: Yes
# Path: ['Itawamba County, Mississippi', 'U.S. state', 'Oklahoma', '2006', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 30.445290088653564
# Number of Nodes Visited: 613
# --- IDFS ---
# Path Exists: Yes
# Path: ['Itawamba County, Mississippi', 'County (United States)', 'Los Angeles County, California', 'Activision Blizzard', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 0.3579680919647217
# Number of Nodes Visited: 26164
#
#
# 73
# --- Run 73 with Starting Article: 1983 ---
# --- BFS ---
# Path Exists: Yes
# Path: ['1983', 'April 14', '2011', 'Minecraft']
# Path Length: 4
# Runtime: 0.8558151721954346
# Number of Nodes Visited: 21626
# --- A* ---
# Path Exists: Yes
# Path: ['1983', 'September 1', '2011', 'Minecraft']
# Path Length: 4
# Runtime: 3.812685251235962
# Number of Nodes Visited: 15
# --- IDFS ---
# Path Exists: Yes
# Path: ['1983', 'April 14', '2011', 'Minecraft']
# Path Length: 4
# Runtime: 0.018949031829833984
# Number of Nodes Visited: 697
#
#
# 74
# --- Run 74 with Starting Article: Seventeen Moments of Spring ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Seventeen Moments of Spring', 'Yekaterina Gradova', 'Moscow', 'Pyongyang', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.20250940322875977
# Number of Nodes Visited: 35379
# --- A* ---
# Path Exists: Yes
# Path: ['Seventeen Moments of Spring', 'Soviet Union', 'World War I', '1917', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 13.76891279220581
# Number of Nodes Visited: 253
# --- IDFS ---
# Path Exists: Yes
# Path: ['Seventeen Moments of Spring', 'Yekaterina Gradova', 'Moscow', 'Pyongyang', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.14020752906799316
# Number of Nodes Visited: 10842
#
#
# 75
# --- Run 75 with Starting Article: Tight end ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Tight end', 'Todd Heap', 'Baltimore', 'Greece', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.938922643661499
# Number of Nodes Visited: 45463
# --- A* ---
# Path Exists: Yes
# Path: ['Tight end', 'American football', 'Season (sports)', 'April', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 9.291672229766846
# Number of Nodes Visited: 88
# --- IDFS ---
# Path Exists: Yes
# Path: ['Tight end', 'Todd Heap', 'Baltimore', 'Greece', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.1656627655029297
# Number of Nodes Visited: 11566
#
#
# 76
# --- Run 76 with Starting Article: St. Lawrence Island ---
# --- BFS ---
# Path Exists: Yes
# Path: ['St. Lawrence Island', 'Russia', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.2531757354736328
# Number of Nodes Visited: 39228
# --- A* ---
# Path Exists: Yes
# Path: ['St. Lawrence Island', 'United States', 'Activision Blizzard', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 11.401031017303467
# Number of Nodes Visited: 209
# --- IDFS ---
# Path Exists: Yes
# Path: ['St. Lawrence Island', 'Russia', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.19098782539367676
# Number of Nodes Visited: 13620
#
#
# 77
# --- Run 77 with Starting Article: Mineralnye Vody ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Mineralnye Vody', 'Russia', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.9457836151123047
# Number of Nodes Visited: 29498
# --- A* ---
# Path Exists: Yes
# Path: ['Mineralnye Vody', 'Russia', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 8.709943771362305
# Number of Nodes Visited: 180
# --- IDFS ---
# Path Exists: Yes
# Path: ['Mineralnye Vody', 'Russia', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.09432482719421387
# Number of Nodes Visited: 7071
#
#
# 78
# --- Run 78 with Starting Article: T. K. Carter ---
# --- BFS ---
# Path Exists: Yes
# Path: ['T. K. Carter', 'Actor', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.12009263038635254
# Number of Nodes Visited: 14760
# --- A* ---
# Path Exists: Yes
# Path: ['T. K. Carter', 'Actor', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 8.038573980331421
# Number of Nodes Visited: 105
# --- IDFS ---
# Path Exists: Yes
# Path: ['T. K. Carter', 'Actor', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.015999317169189453
# Number of Nodes Visited: 1245
#
#
# 79
# --- Run 79 with Starting Article: Intracerebral hemorrhage ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Intracerebral hemorrhage', 'Fever', 'Infection', 'Bubonic plague', '20th century', '2011', 'Minecraft']
# Path Length: 7
# Runtime: 0.200087308883667
# Number of Nodes Visited: 35751
# --- A* ---
# Path Exists: Yes
# Path: ['Intracerebral hemorrhage', 'Fever', 'Celsius', 'Sweden', '1995', 'Microsoft', 'Minecraft']
# Path Length: 7
# Runtime: 10.65024209022522
# Number of Nodes Visited: 143
# --- IDFS ---
# Path Exists: Yes
# Path: ['Intracerebral hemorrhage', 'Fever', 'Infection', 'Bubonic plague', '20th century', '2011', 'Minecraft']
# Path Length: 7
# Runtime: 0.07925009727478027
# Number of Nodes Visited: 5102
#
#
# 80
# --- Run 80 with Starting Article: Wichita Dwight D. Eisenhower National Airport ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Wichita Dwight D. Eisenhower National Airport', 'Wichita, Kansas', 'Baseball', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 0.9980101585388184
# Number of Nodes Visited: 52235
# --- A* ---
# Path Exists: Yes
# Path: ['Wichita Dwight D. Eisenhower National Airport', 'Wichita, Kansas', 'NBC', 'MSNBC', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 6.592416524887085
# Number of Nodes Visited: 108
# --- IDFS ---
# Path Exists: Yes
# Path: ['Wichita Dwight D. Eisenhower National Airport', 'Wichita, Kansas', 'Baseball', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 0.3484811782836914
# Number of Nodes Visited: 25678
#
#
# 81
# --- Run 81 with Starting Article: Dresden, Kansas ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Dresden, Kansas', 'City', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.9869568347930908
# Number of Nodes Visited: 64304
# --- A* ---
# Path Exists: Yes
# Path: ['Dresden, Kansas', 'United States', 'Activision Blizzard', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 17.044089555740356
# Number of Nodes Visited: 292
# --- IDFS ---
# Path Exists: Yes
# Path: ['Dresden, Kansas', 'City', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.4704113006591797
# Number of Nodes Visited: 32797
#
#
# 82
# --- Run 82 with Starting Article: Villeneuve-la-Comtesse ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Villeneuve-la-Comtesse', 'Departments of France', 'Guéret', 'Wolf', 'Minecraft']
# Path Length: 5
# Runtime: 0.13518500328063965
# Number of Nodes Visited: 20010
# --- A* ---
# Path Exists: Yes
# Path: ['Villeneuve-la-Comtesse', 'France', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 5.437547922134399
# Number of Nodes Visited: 81
# --- IDFS ---
# Path Exists: Yes
# Path: ['Villeneuve-la-Comtesse', 'Departments of France', 'Guéret', 'Wolf', 'Minecraft']
# Path Length: 5
# Runtime: 0.05585122108459473
# Number of Nodes Visited: 3387
#
#
# 83
# --- Run 83 with Starting Article: Centese Calcio ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Centese Calcio', 'Italy', 'Mario Draghi', 'Mario', 'Minecraft']
# Path Length: 5
# Runtime: 0.11620736122131348
# Number of Nodes Visited: 10731
# --- A* ---
# Path Exists: Yes
# Path: ['Centese Calcio', 'Italy', 'Mario Draghi', 'Mario', 'Minecraft']
# Path Length: 5
# Runtime: 7.0787694454193115
# Number of Nodes Visited: 114
# --- IDFS ---
# Path Exists: Yes
# Path: ['Centese Calcio', 'Italy', 'Mario Draghi', 'Mario', 'Minecraft']
# Path Length: 5
# Runtime: 0.01564764976501465
# Number of Nodes Visited: 688
#
#
# 84
# --- Run 84 with Starting Article: Crittenden County, Arkansas ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Crittenden County, Arkansas', 'County (United States)', 'Los Angeles County, California', 'Activision Blizzard', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 0.9479899406433105
# Number of Nodes Visited: 53121
# --- A* ---
# Path Exists: Yes
# Path: ['Crittenden County, Arkansas', 'U.S. state', 'Utah', 'October', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 18.745426416397095
# Number of Nodes Visited: 401
# --- IDFS ---
# Path Exists: Yes
# Path: ['Crittenden County, Arkansas', 'County (United States)', 'Los Angeles County, California', 'Activision Blizzard', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 0.3768446445465088
# Number of Nodes Visited: 27235
#
#
# 85
# --- Run 85 with Starting Article: Galle ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Galle', 'UNESCO', '1945', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.18828272819519043
# Number of Nodes Visited: 38770
# --- A* ---
# Path Exists: Yes
# Path: ['Galle', 'Sri Lanka', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 3.2579338550567627
# Number of Nodes Visited: 82
# --- IDFS ---
# Path Exists: Yes
# Path: ['Galle', 'UNESCO', '1945', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.10973405838012695
# Number of Nodes Visited: 3178
#
#
# 86
# --- Run 86 with Starting Article: White Rock, British Columbia ---
# --- BFS ---
# Path Exists: Yes
# Path: ['White Rock, British Columbia', 'Canada', 'Saint Lawrence Seaway', '20th century', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 1.0053586959838867
# Number of Nodes Visited: 57821
# --- A* ---
# Path Exists: Yes
# Path: ['White Rock, British Columbia', 'Canada', 'Charles III', '2022', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 16.467052936553955
# Number of Nodes Visited: 281
# --- IDFS ---
# Path Exists: Yes
# Path: ['White Rock, British Columbia', 'Canada', 'Saint Lawrence Seaway', '20th century', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.4474601745605469
# Number of Nodes Visited: 26929
#
#
# 87
# --- Run 87 with Starting Article: Maisons-Laffitte ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Maisons-Laffitte', 'Departments of France', 'Guéret', 'Wolf', 'Minecraft']
# Path Length: 5
# Runtime: 0.1422286033630371
# Number of Nodes Visited: 19999
# --- A* ---
# Path Exists: Yes
# Path: ['Maisons-Laffitte', 'Departments of France', 'Guéret', 'Wolf', 'Minecraft']
# Path Length: 5
# Runtime: 6.601898193359375
# Number of Nodes Visited: 160
# --- IDFS ---
# Path Exists: Yes
# Path: ['Maisons-Laffitte', 'Departments of France', 'Guéret', 'Wolf', 'Minecraft']
# Path Length: 5
# Runtime: 0.044524192810058594
# Number of Nodes Visited: 3384
#
#
# 88
# --- Run 88 with Starting Article: B.O.C Road ---
# --- BFS ---
# Path Exists: Yes
# Path: ['B.O.C Road', 'India', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.90085768699646
# Number of Nodes Visited: 20291
# --- A* ---
# Path Exists: Yes
# Path: ['B.O.C Road', 'India', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 4.84548544883728
# Number of Nodes Visited: 103
# --- IDFS ---
# Path Exists: Yes
# Path: ['B.O.C Road', 'India', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.0469050407409668
# Number of Nodes Visited: 3890
#
#
# 89
# --- Run 89 with Starting Article: List of U.S. state ships ---
# --- BFS ---
# Path Exists: Yes
# Path: ['List of U.S. state ships', 'Connecticut', 'Mohegan', 'Wolf', 'Minecraft']
# Path Length: 5
# Runtime: 0.2250680923461914
# Number of Nodes Visited: 32355
# --- A* ---
# Path Exists: Yes
# Path: ['List of U.S. state ships', 'Connecticut', 'Mohegan', 'Wolf', 'Minecraft']
# Path Length: 5
# Runtime: 9.259303092956543
# Number of Nodes Visited: 161
# --- IDFS ---
# Path Exists: Yes
# Path: ['List of U.S. state ships', 'Connecticut', 'Mohegan', 'Wolf', 'Minecraft']
# Path Length: 5
# Runtime: 0.1266922950744629
# Number of Nodes Visited: 8023
#
#
# 90
# --- Run 90 with Starting Article: Elle (magazine) ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Elle (magazine)', 'Greece', '2011', 'Minecraft']
# Path Length: 4
# Runtime: 0.21449971199035645
# Number of Nodes Visited: 21093
# --- A* ---
# Path Exists: Yes
# Path: ['Elle (magazine)', 'Greece', '2011', 'Minecraft']
# Path Length: 4
# Runtime: 7.581214904785156
# Number of Nodes Visited: 17
# --- IDFS ---
# Path Exists: Yes
# Path: ['Elle (magazine)', 'Greece', '2011', 'Minecraft']
# Path Length: 4
# Runtime: 0.035639286041259766
# Number of Nodes Visited: 1819
#
#
# 91
# --- Run 91 with Starting Article: Tage Erlander ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Tage Erlander', 'Sweden', '1995', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.9806137084960938
# Number of Nodes Visited: 28274
# --- A* ---
# Path Exists: Yes
# Path: ['Tage Erlander', 'Sweden', '1995', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 3.561630964279175
# Number of Nodes Visited: 30
# --- IDFS ---
# Path Exists: Yes
# Path: ['Tage Erlander', 'Sweden', '1995', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.03943514823913574
# Number of Nodes Visited: 1596
#
#
# 92
# 93
# --- Run 93 with Starting Article: Gruiformes ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Gruiformes', 'Animal', 'Earth', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.10630297660827637
# Number of Nodes Visited: 14264
# --- A* ---
# Path Exists: Yes
# Path: ['Gruiformes', 'Animal', 'Earth', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 7.005437850952148
# Number of Nodes Visited: 162
# --- IDFS ---
# Path Exists: Yes
# Path: ['Gruiformes', 'Animal', 'Earth', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.02892279624938965
# Number of Nodes Visited: 3184
#
#
# 94
# 95
# --- Run 95 with Starting Article: Stora Vika ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Stora Vika', 'Sweden', '1995', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 1.0053579807281494
# Number of Nodes Visited: 28123
# --- A* ---
# Path Exists: Yes
# Path: ['Stora Vika', 'Sweden', '1995', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 11.545427560806274
# Number of Nodes Visited: 188
# --- IDFS ---
# Path Exists: Yes
# Path: ['Stora Vika', 'Sweden', '1995', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.03744769096374512
# Number of Nodes Visited: 1687
#
#
# 96
# --- Run 96 with Starting Article: Margaret of Valois ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Margaret of Valois', 'Charles IX of France', 'June 27', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.1637880802154541
# Number of Nodes Visited: 23914
# --- A* ---
# Path Exists: Yes
# Path: ['Margaret of Valois', 'Henry III of France', 'September 19', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 5.744201898574829
# Number of Nodes Visited: 30
# --- IDFS ---
# Path Exists: Yes
# Path: ['Margaret of Valois', 'Charles IX of France', 'June 27', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.05037569999694824
# Number of Nodes Visited: 2778
#
#
# 97
# --- Run 97 with Starting Article: Arkose ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Arkose', 'Uluru', 'Uluṟu-Kata Tjuṯa National Park', 'Copyright', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 0.10933685302734375
# Number of Nodes Visited: 12885
# --- A* ---
# Path Exists: Yes
# Path: ['Arkose', 'Cambrian', 'Burgess Shale', '21st century', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 4.376983642578125
# Number of Nodes Visited: 49
# --- IDFS ---
# Path Exists: Yes
# Path: ['Arkose', 'Uluru', 'Uluṟu-Kata Tjuṯa National Park', 'Copyright', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 0.014986038208007812
# Number of Nodes Visited: 1373
#
#
# 98
# --- Run 98 with Starting Article: Flagey, Doubs ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Flagey, Doubs', 'Departments of France', 'Guéret', 'Wolf', 'Minecraft']
# Path Length: 5
# Runtime: 0.8946816921234131
# Number of Nodes Visited: 24980
# --- A* ---
# Path Exists: Yes
# Path: ['Flagey, Doubs', 'Departments of France', 'Guéret', 'Wolf', 'Minecraft']
# Path Length: 5
# Runtime: 10.492929220199585
# Number of Nodes Visited: 224
# --- IDFS ---
# Path Exists: Yes
# Path: ['Flagey, Doubs', 'Departments of France', 'Guéret', 'Wolf', 'Minecraft']
# Path Length: 5
# Runtime: 0.09688949584960938
# Number of Nodes Visited: 5393
#
#
# 99
# --- Run 99 with Starting Article: Seong Hon ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Seong Hon', 'Yi I', 'Korea', 'Pyongyang', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.11221194267272949
# Number of Nodes Visited: 9336
# --- A* ---
# Path Exists: Yes
# Path: ['Seong Hon', 'Kim Jang-saeng', 'Korea', 'Pyongyang', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 10.146930694580078
# Number of Nodes Visited: 174
# --- IDFS ---
# Path Exists: Yes
# Path: ['Seong Hon', 'Yi I', 'Korea', 'Pyongyang', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.012960433959960938
# Number of Nodes Visited: 867
#
#
# 100
# --- Run 100 with Starting Article: Sofia Stefan ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Sofia Stefan', 'Italy', 'Mario Draghi', 'Mario', 'Minecraft']
# Path Length: 5
# Runtime: 0.12782979011535645
# Number of Nodes Visited: 9870
# --- A* ---
# Path Exists: Yes
# Path: ['Sofia Stefan', 'Italy', 'Mario Draghi', 'Mario', 'Minecraft']
# Path Length: 5
# Runtime: 6.000490665435791
# Number of Nodes Visited: 86
# --- IDFS ---
# Path Exists: Yes
# Path: ['Sofia Stefan', 'Italy', 'Mario Draghi', 'Mario', 'Minecraft']
# Path Length: 5
# Runtime: 0.008968830108642578
# Number of Nodes Visited: 616

# %%
# Tính kết quả trung bình
bfs_average_path_length = bfs_total_path_length / \
    bfs_path_exists_count if bfs_path_exists_count > 0 else 0
astar_average_path_length = astar_total_path_length / \
    astar_path_exists_count if astar_path_exists_count > 0 else 0
idfs_average_path_length = idfs_total_path_length / \
    idfs_path_exists_count if idfs_path_exists_count > 0 else 0
bfs_average_node_count = bfs_total_node_count / valid_runs
astar_average_node_count = astar_total_node_count / valid_runs
idfs_average_node_count = idfs_total_node_count / valid_runs
bfs_average_runtime = bfs_total_runtime / valid_runs if valid_runs > 0 else 0
astar_average_runtime = astar_total_runtime / valid_runs if valid_runs > 0 else 0
idfs_average_runtime = idfs_total_runtime / valid_runs if valid_runs > 0 else 0

# In thống kế
print("--- Overall Results ---")
print("Number of Runs:", run_count)
print("BFS Path Exists Count:", bfs_path_exists_count)
print("BFS Average Path Length:", bfs_average_path_length)
print("BFS Average Number of Nodes Visited:", bfs_average_node_count)
print("BFS Average Runtime:", bfs_average_runtime)
print("\n")
print("A* Path Exists Count:", astar_path_exists_count)
print("A* Average Path Length:", astar_average_path_length)
print("A* Average Number of Nodes Visited:", astar_average_node_count)
print("A* Average Runtime:", astar_average_runtime)
print("\n")
print("IDFS Path Exists Count:", idfs_path_exists_count)
print("IDFS Average Path Length:", idfs_average_path_length)
print("IDFS Average Number of Nodes Visited:", idfs_average_node_count)
print("IDFS Average Runtime:", idfs_average_runtime)
# Out:
# --- Overall Results ---
# Number of Runs: 100
# BFS Path Exists Count: 98
# BFS Average Path Length: 5.204081632653061
# BFS Average Number of Nodes Visited: 29365.132653061224
# BFS Average Runtime: 0.48713829566021355
#
#
# A* Path Exists Count: 98
# A* Average Path Length: 5.214285714285714
# A* Average Number of Nodes Visited: 142.19387755102042
# A* Average Runtime: 9.13967526932152
#
#
# IDFS Path Exists Count: 98
# IDFS Average Path Length: 5.204081632653061
# IDFS Average Number of Nodes Visited: 7244.724489795918
# IDFS Average Runtime: 0.11069836665172966

# %%
# Tạo đồ thị cột cho số đường đi trung bình
x = ["BFS", "A*", "IDFS"]
y = [bfs_average_path_length, astar_average_path_length, idfs_average_path_length]
plt.bar(x, y)
plt.xlabel("Algorithm")
plt.ylabel("Average Path Length")
plt.title("Average Path Length")
plt.show()

# Tạo đồ thị cột cho số node xét
x = ["BFS", "A*", "IDFS"]
y = [bfs_average_node_count, astar_average_node_count, idfs_average_node_count]
plt.bar(x, y)
plt.xlabel("Algorithm")
plt.ylabel("Average Number of Nodes Visited")
plt.title("Average Number of Nodes Visited")
plt.show()

# Tạo đồ thị cột cho thời gian chạy trung bình
x = ["BFS", "A*", "IDFS"]
y = [bfs_average_runtime, astar_average_runtime, idfs_average_runtime]
plt.bar(x, y)
plt.xlabel("Algorithm")
plt.ylabel("Average Runtime")
plt.title("Average Runtime")
plt.show()
