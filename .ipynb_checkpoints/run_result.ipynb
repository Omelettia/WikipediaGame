# %% [markdown]
# #9. Code để thống kê và so sánh kết quả khi chạy 3 thuật toán BFS, IDDFS, A*

# %%
pip install matplotlib

# %%
import pickle
import matplotlib.pyplot as plt
import BFS
import A_search
import IDDFS

# %%
# Load đồ thị
file_path = r"graph_with_attributes.pkl"
with open(file_path, "rb") as file:
    graph = pickle.load(file)

# Cố dịnh ending article
ending_article = "Minecraft"

#Đọc các starting articles từ file với UTF-8
with open("randomized_article_names.txt", "r", encoding="utf-8") as file:
    starting_articles = file.read().splitlines()

# %%
# Số lần chạy
num_runs = 1000

# Thiết lập biến để đếm
bfs_path_exists_count = 0
astar_path_exists_count = 0
idfs_path_exists_count = 0
bfs_total_path_length = 0
astar_total_path_length = 0
idfs_total_path_length = 0
bfs_total_node_count = 0
astar_total_node_count = 0
idfs_total_node_count = 0
bfs_total_runtime = 0
idfs_total_runtime = 0
astar_total_runtime = 0
run_count = 0
valid_runs = 0

# %%
# Thực hiện các lần chạy
for starting_article in starting_articles:
    if run_count == num_runs:
        break

    run_count += 1
    print(run_count)
    # Thực hiênh BFS
    bfs_path_length, bfs_path, bfs_runtime, bfs_node_count = BFS.bfs_search(
        graph, starting_article, ending_article)
    if bfs_path_length is None:
        astar_path, astar_path_length, astar_runtime, astar_node_count = None, None, None, None
        idfs_path, idfs_path_length, idfs_runtime, idfs_node_count = None, None, None, None
        continue
    # Thực hiện A*
    astar_path, astar_node_count, astar_runtime, astar_path_length = A_search.astar(graph, starting_article,
                                                                                    ending_article)

    # Thực hiện IDDFS
    idfs_path, idfs_path_length, idfs_runtime, idfs_node_count = IDDFS.iddfs_search(graph, starting_article,
                                                                                    ending_article, 10)

    # Cập nhật các biến đếm
    if bfs_path_length is not None:
        valid_runs += 1
        bfs_path_exists_count += 1
        bfs_total_path_length += bfs_path_length
        bfs_total_runtime += bfs_runtime

    if astar_path_length is not None:
        astar_path_exists_count += 1
        astar_total_path_length += astar_path_length
        astar_total_runtime += astar_runtime

    if idfs_path_length is not None:
        idfs_path_exists_count += 1
        idfs_total_path_length += idfs_path_length
        idfs_total_runtime += idfs_runtime

    bfs_total_node_count += bfs_node_count
    astar_total_node_count += astar_node_count
    idfs_total_node_count += idfs_node_count

    # In kết quả
    print("--- Run", run_count, "with Starting Article:", starting_article, "---")
    print("--- BFS ---")
    if bfs_path_length is not None:
        print("Path Exists: Yes")
        print("Path:", bfs_path)
        print("Path Length:", bfs_path_length)
    else:
        print("Path Exists: No")
    print("Runtime:", bfs_runtime)
    print("Number of Nodes Visited:", bfs_node_count)

    print("--- A* ---")
    if astar_path_length is not None:
        print("Path Exists: Yes")
        print("Path:", astar_path)
        print("Path Length:", astar_path_length)
    else:
        print("Path Exists: No")
    print("Runtime:", astar_runtime)
    print("Number of Nodes Visited:", astar_node_count)

    print("--- IDFS ---")
    if idfs_path_length is not None:
        print("Path Exists: Yes")
        print("Path:", idfs_path)
        print("Path Length:", idfs_path_length)
    else:
        print("Path Exists: No")
    print("Runtime:", idfs_runtime)
    print("Number of Nodes Visited:", idfs_node_count)
    print("\n")
# Out:
# 1
# 2
# --- Run 2 with Starting Article: London Underground C69 and C77 Stock ---
# --- BFS ---
# Path Exists: Yes
# Path: ['London Underground C69 and C77 Stock', 'England', 'University of Cambridge', 'October', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 1.022505521774292
# Number of Nodes Visited: 38826
# --- A* ---
# Path Exists: Yes
# Path: ['London Underground C69 and C77 Stock', 'England', 'BBC', 'BBC iPlayer', 'PlayStation 4', 'Minecraft']
# Path Length: 6
# Runtime: 34.646296977996826
# Number of Nodes Visited: 371
# --- IDFS ---
# Path Exists: Yes
# Path: ['London Underground C69 and C77 Stock', 'England', 'University of Cambridge', 'October', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.13164758682250977
# Number of Nodes Visited: 10811
#
#
# 3
# --- Run 3 with Starting Article: Welsh Marches ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Welsh Marches', 'England', 'University of Cambridge', 'October', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.23640155792236328
# Number of Nodes Visited: 46589
# --- A* ---
# Path Exists: Yes
# Path: ['Welsh Marches', 'England', 'Mary II of England', '2006', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 36.478076696395874
# Number of Nodes Visited: 547
# --- IDFS ---
# Path Exists: Yes
# Path: ['Welsh Marches', 'England', 'University of Cambridge', 'October', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.3171517848968506
# Number of Nodes Visited: 28660
#
#
# 4
# --- Run 4 with Starting Article: Roberto Soldado ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Roberto Soldado', '1985', 'Microsoft', 'Minecraft']
# Path Length: 4
# Runtime: 0.7339668273925781
# Number of Nodes Visited: 8923
# --- A* ---
# Path Exists: Yes
# Path: ['Roberto Soldado', '1985', 'Microsoft', 'Minecraft']
# Path Length: 4
# Runtime: 1.2853600978851318
# Number of Nodes Visited: 4
# --- IDFS ---
# Path Exists: Yes
# Path: ['Roberto Soldado', '1985', 'Microsoft', 'Minecraft']
# Path Length: 4
# Runtime: 0.0049839019775390625
# Number of Nodes Visited: 359
#
#
# 5
# --- Run 5 with Starting Article: Marthe Bogaerts ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Marthe Bogaerts', 'Paris', 'Julius Caesar', 'Greece', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.1515946388244629
# Number of Nodes Visited: 29142
# --- A* ---
# Path Exists: Yes
# Path: ['Marthe Bogaerts', 'Paris', 'Italy', '2022', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 23.35245108604431
# Number of Nodes Visited: 187
# --- IDFS ---
# Path Exists: Yes
# Path: ['Marthe Bogaerts', 'Paris', 'Julius Caesar', 'Greece', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.06386041641235352
# Number of Nodes Visited: 5883
#
#
# 6
# --- Run 6 with Starting Article: Wait (Beatles song) ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Wait (Beatles song)', 'George Martin', '1990s', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.7420153617858887
# Number of Nodes Visited: 21647
# --- A* ---
# Path Exists: Yes
# Path: ['Wait (Beatles song)', 'George Martin', '1990s', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 11.107974767684937
# Number of Nodes Visited: 118
# --- IDFS ---
# Path Exists: Yes
# Path: ['Wait (Beatles song)', 'George Martin', '1990s', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.05086255073547363
# Number of Nodes Visited: 5037
#
#
# 7
# 8
# --- Run 8 with Starting Article: Cossato ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Cossato', 'Italy', '2022', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.16316914558410645
# Number of Nodes Visited: 36695
# --- A* ---
# Path Exists: Yes
# Path: ['Cossato', 'Italy', '2022', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 12.47615909576416
# Number of Nodes Visited: 61
# --- IDFS ---
# Path Exists: Yes
# Path: ['Cossato', 'Italy', '2022', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.0418848991394043
# Number of Nodes Visited: 2531
#
#
# 9
# --- Run 9 with Starting Article: Sophie Cookson ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Sophie Cookson', 'England', 'University of Cambridge', 'October', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.8201305866241455
# Number of Nodes Visited: 35878
# --- A* ---
# Path Exists: Yes
# Path: ['Sophie Cookson', 'West Sussex', 'Local Government Act 1972', 'Merthyr Tydfil', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 26.566184520721436
# Number of Nodes Visited: 498
# --- IDFS ---
# Path Exists: Yes
# Path: ['Sophie Cookson', 'England', 'University of Cambridge', 'October', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.08676791191101074
# Number of Nodes Visited: 8119
#
#
# 10
# --- Run 10 with Starting Article: Delano, California ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Delano, California', 'United States', 'Xbox Game Studios', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.17256855964660645
# Number of Nodes Visited: 39907
# --- A* ---
# Path Exists: Yes
# Path: ['Delano, California', 'California', 'Technology company', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 7.390819311141968
# Number of Nodes Visited: 55
# --- IDFS ---
# Path Exists: Yes
# Path: ['Delano, California', 'United States', 'Xbox Game Studios', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.10574913024902344
# Number of Nodes Visited: 10013
#
#
# 11
# --- Run 11 with Starting Article: Sacrilege ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Sacrilege', 'Taboo', 'Islam', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 0.7838196754455566
# Number of Nodes Visited: 30405
# --- A* ---
# Path Exists: Yes
# Path: ['Sacrilege', 'Taboo', 'Islam', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 19.722497701644897
# Number of Nodes Visited: 282
# --- IDFS ---
# Path Exists: Yes
# Path: ['Sacrilege', 'Taboo', 'Islam', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 0.09474658966064453
# Number of Nodes Visited: 8933
#
#
# 12
# --- Run 12 with Starting Article: Lorquí ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Lorquí', 'Spain', '20th century', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.14331293106079102
# Number of Nodes Visited: 24261
# --- A* ---
# Path Exists: Yes
# Path: ['Lorquí', 'Spain', '20th century', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 8.112379312515259
# Number of Nodes Visited: 101
# --- IDFS ---
# Path Exists: Yes
# Path: ['Lorquí', 'Spain', '20th century', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.0498964786529541
# Number of Nodes Visited: 4643
#
#
# 13
# --- Run 13 with Starting Article: Dassault/Dornier Alpha Jet ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Dassault/Dornier Alpha Jet', 'France', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.8449621200561523
# Number of Nodes Visited: 48158
# --- A* ---
# Path Exists: Yes
# Path: ['Dassault/Dornier Alpha Jet', 'France', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 4.497464656829834
# Number of Nodes Visited: 14
# --- IDFS ---
# Path Exists: Yes
# Path: ['Dassault/Dornier Alpha Jet', 'France', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.15957355499267578
# Number of Nodes Visited: 14065
#
#
# 14
# --- Run 14 with Starting Article: List of cities in Serbia ---
# --- BFS ---
# Path Exists: Yes
# Path: ['List of cities in Serbia', '2011', 'Minecraft']
# Path Length: 3
# Runtime: 0.014521360397338867
# Number of Nodes Visited: 479
# --- A* ---
# Path Exists: Yes
# Path: ['List of cities in Serbia', '2011', 'Minecraft']
# Path Length: 3
# Runtime: 1.9098913669586182
# Number of Nodes Visited: 3
# --- IDFS ---
# Path Exists: Yes
# Path: ['List of cities in Serbia', '2011', 'Minecraft']
# Path Length: 3
# Runtime: 0.0
# Number of Nodes Visited: 14
#
#
# 15
# --- Run 15 with Starting Article: Ralph Wilson ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Ralph Wilson', 'MSN', 'Microsoft', 'Minecraft']
# Path Length: 4
# Runtime: 0.052858829498291016
# Number of Nodes Visited: 3922
# --- A* ---
# Path Exists: Yes
# Path: ['Ralph Wilson', 'MSN', 'Microsoft', 'Minecraft']
# Path Length: 4
# Runtime: 0.6326630115509033
# Number of Nodes Visited: 9
# --- IDFS ---
# Path Exists: Yes
# Path: ['Ralph Wilson', 'MSN', 'Microsoft', 'Minecraft']
# Path Length: 4
# Runtime: 0.001995563507080078
# Number of Nodes Visited: 83
#
#
# 16
# --- Run 16 with Starting Article: Calcio Foggia 1920 ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Calcio Foggia 1920', 'Italy', '2022', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.7948713302612305
# Number of Nodes Visited: 34546
# --- A* ---
# Path Exists: Yes
# Path: ['Calcio Foggia 1920', 'Italy', '2022', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 14.421228885650635
# Number of Nodes Visited: 64
# --- IDFS ---
# Path Exists: Yes
# Path: ['Calcio Foggia 1920', 'Italy', '2022', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.03547215461730957
# Number of Nodes Visited: 1890
#
#
# 17
# --- Run 17 with Starting Article: Graffiti (album) ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Graffiti (album)', 'Dance music', '20th century', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.17054343223571777
# Number of Nodes Visited: 40148
# --- A* ---
# Path Exists: Yes
# Path: ['Graffiti (album)', 'Polow da Don', 'June 4', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 15.541104555130005
# Number of Nodes Visited: 165
# --- IDFS ---
# Path Exists: Yes
# Path: ['Graffiti (album)', 'Dance music', '20th century', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.09976530075073242
# Number of Nodes Visited: 9579
#
#
# 18
# --- Run 18 with Starting Article: Little Richard ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Little Richard', 'United States', 'Xbox Game Studios', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.8097448348999023
# Number of Nodes Visited: 40513
# --- A* ---
# Path Exists: Yes
# Path: ['Little Richard', 'United States', 'Xbox Game Studios', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 10.49947452545166
# Number of Nodes Visited: 125
# --- IDFS ---
# Path Exists: Yes
# Path: ['Little Richard', 'United States', 'Xbox Game Studios', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.10970664024353027
# Number of Nodes Visited: 10249
#
#
# 19
# --- Run 19 with Starting Article: Fort Stockton, Texas ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Fort Stockton, Texas', 'U.S. state', 'Tennessee', 'Raccoon', 'Wolf', 'Minecraft']
# Path Length: 6
# Runtime: 0.14760518074035645
# Number of Nodes Visited: 29257
# --- A* ---
# Path Exists: Yes
# Path: ['Fort Stockton, Texas', 'U.S. state', 'North Dakota', 'November 2', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 20.710753679275513
# Number of Nodes Visited: 178
# --- IDFS ---
# Path Exists: Yes
# Path: ['Fort Stockton, Texas', 'U.S. state', 'Tennessee', 'Raccoon', 'Wolf', 'Minecraft']
# Path Length: 6
# Runtime: 0.0967409610748291
# Number of Nodes Visited: 9668
#
#
# 20
# --- Run 20 with Starting Article: Lichtentaler Allee ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Lichtentaler Allee', '19th century', 'The Jungle Book', 'Wolf', 'Minecraft']
# Path Length: 5
# Runtime: 0.1904892921447754
# Number of Nodes Visited: 49392
# --- A* ---
# Path Exists: Yes
# Path: ['Lichtentaler Allee', '19th century', 'The Jungle Book', 'Wolf', 'Minecraft']
# Path Length: 5
# Runtime: 10.806812047958374
# Number of Nodes Visited: 155
# --- IDFS ---
# Path Exists: Yes
# Path: ['Lichtentaler Allee', '19th century', 'The Jungle Book', 'Wolf', 'Minecraft']
# Path Length: 5
# Runtime: 0.1985013484954834
# Number of Nodes Visited: 5878
#
#
# 21
# --- Run 21 with Starting Article: David Bustamante ---
# --- BFS ---
# Path Exists: Yes
# Path: ['David Bustamante', 'Pop music', '1990s', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.7336184978485107
# Number of Nodes Visited: 17230
# --- A* ---
# Path Exists: Yes
# Path: ['David Bustamante', 'Pop music', 'Computer', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.7739648818969727
# Number of Nodes Visited: 9
# --- IDFS ---
# Path Exists: Yes
# Path: ['David Bustamante', 'Pop music', '1990s', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.015956640243530273
# Number of Nodes Visited: 1480
#
#
# 22
# --- Run 22 with Starting Article: Jigme Thinley ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Jigme Thinley', 'Pennsylvania State University', 'U.S. News & World Report', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 0.13862872123718262
# Number of Nodes Visited: 29526
# --- A* ---
# Path Exists: Yes
# Path: ['Jigme Thinley', 'Pennsylvania State University', 'Association of American Universities', 'Harvard University', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 27.01245903968811
# Number of Nodes Visited: 483
# --- IDFS ---
# Path Exists: Yes
# Path: ['Jigme Thinley', 'Pennsylvania State University', 'U.S. News & World Report', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 0.04886913299560547
# Number of Nodes Visited: 4921
#
#
# 23
# --- Run 23 with Starting Article: Rhodes Scholarship ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Rhodes Scholarship', 'Walter Isaacson', 'Harvard University', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.6835100650787354
# Number of Nodes Visited: 8809
# --- A* ---
# Path Exists: Yes
# Path: ['Rhodes Scholarship', 'Walter Isaacson', 'Steve Jobs', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 15.502710103988647
# Number of Nodes Visited: 151
# --- IDFS ---
# Path Exists: Yes
# Path: ['Rhodes Scholarship', 'Walter Isaacson', 'Harvard University', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.005984306335449219
# Number of Nodes Visited: 453
#
#
# 24
# --- Run 24 with Starting Article: Gosnold, Massachusetts ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Gosnold, Massachusetts', 'Massachusetts', 'Harvard University', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.11070632934570312
# Number of Nodes Visited: 18602
# --- A* ---
# Path Exists: Yes
# Path: ['Gosnold, Massachusetts', 'United States', 'Xbox Game Studios', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 2.426358461380005
# Number of Nodes Visited: 11
# --- IDFS ---
# Path Exists: Yes
# Path: ['Gosnold, Massachusetts', 'Massachusetts', 'Harvard University', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.027922868728637695
# Number of Nodes Visited: 2771
#
#
# 25
# --- Run 25 with Starting Article: Saskatoon ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Saskatoon', 'University of Saskatchewan', '2001', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.13261079788208008
# Number of Nodes Visited: 28629
# --- A* ---
# Path Exists: Yes
# Path: ['Saskatoon', 'University of Saskatchewan', '1925', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 3.23565411567688
# Number of Nodes Visited: 11
# --- IDFS ---
# Path Exists: Yes
# Path: ['Saskatoon', 'University of Saskatchewan', '2001', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.03191494941711426
# Number of Nodes Visited: 1130
#
#
# 26
# --- Run 26 with Starting Article: List of counties in West Virginia ---
# --- BFS ---
# Path Exists: Yes
# Path: ['List of counties in West Virginia', 'West Virginia', 'American black bear', 'Wolf', 'Minecraft']
# Path Length: 5
# Runtime: 0.8197758197784424
# Number of Nodes Visited: 50721
# --- A* ---
# Path Exists: Yes
# Path: ['List of counties in West Virginia', 'John Hancock', 'October 8', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 14.731231927871704
# Number of Nodes Visited: 182
# --- IDFS ---
# Path Exists: Yes
# Path: ['List of counties in West Virginia', 'West Virginia', 'American black bear', 'Wolf', 'Minecraft']
# Path Length: 5
# Runtime: 0.24036335945129395
# Number of Nodes Visited: 21791
#
#
# 27
# --- Run 27 with Starting Article: Los Rábanos ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Los Rábanos', 'Spain', '20th century', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.7599284648895264
# Number of Nodes Visited: 23336
# --- A* ---
# Path Exists: Yes
# Path: ['Los Rábanos', 'Spain', '20th century', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 7.696471452713013
# Number of Nodes Visited: 93
# --- IDFS ---
# Path Exists: Yes
# Path: ['Los Rábanos', 'Spain', '20th century', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.04387998580932617
# Number of Nodes Visited: 4084
#
#
# 28
# --- Run 28 with Starting Article: Willandra National Park ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Willandra National Park', 'Riverina', '20th century', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.10953497886657715
# Number of Nodes Visited: 19238
# --- A* ---
# Path Exists: Yes
# Path: ['Willandra National Park', 'Australia', 'Royal Australian Navy', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 9.473215103149414
# Number of Nodes Visited: 94
# --- IDFS ---
# Path Exists: Yes
# Path: ['Willandra National Park', 'Riverina', '20th century', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.03291034698486328
# Number of Nodes Visited: 3004
#
#
# 29
# --- Run 29 with Starting Article: Vadim Petrov ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Vadim Petrov', 'Czechs', 'United States', 'Xbox Game Studios', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 0.17985749244689941
# Number of Nodes Visited: 43596
# --- A* ---
# Path Exists: Yes
# Path: ['Vadim Petrov', 'Prague', 'Czech Airlines', '2015', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 21.713807106018066
# Number of Nodes Visited: 289
# --- IDFS ---
# Path Exists: Yes
# Path: ['Vadim Petrov', 'Czechs', 'United States', 'Xbox Game Studios', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 0.14960002899169922
# Number of Nodes Visited: 13675
#
#
# 30
# --- Run 30 with Starting Article: Fouhren ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Fouhren', 'Luxembourg', 'September', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.7291104793548584
# Number of Nodes Visited: 14120
# --- A* ---
# Path Exists: Yes
# Path: ['Fouhren', 'Luxembourg', 'September', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 5.113706111907959
# Number of Nodes Visited: 36
# --- IDFS ---
# Path Exists: Yes
# Path: ['Fouhren', 'Luxembourg', 'September', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.0179288387298584
# Number of Nodes Visited: 1726
#
#
# 31
# --- Run 31 with Starting Article: Nepal Standard Time ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Nepal Standard Time', 'Time in Australia', 'South Australia', 'November 23', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.12068462371826172
# Number of Nodes Visited: 21970
# --- A* ---
# Path Exists: Yes
# Path: ['Nepal Standard Time', 'Time in Australia', 'Cocos (Keeling) Islands', '1955', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 10.389982223510742
# Number of Nodes Visited: 108
# --- IDFS ---
# Path Exists: Yes
# Path: ['Nepal Standard Time', 'Time in Australia', 'South Australia', 'November 23', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.0359041690826416
# Number of Nodes Visited: 3724
#
#
# 32
# --- Run 32 with Starting Article: Fumigation ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Fumigation', 'Herbicide', 'Vietnam War', 'France', 'Greece', '2011', 'Minecraft']
# Path Length: 7
# Runtime: 0.8455159664154053
# Number of Nodes Visited: 51043
# --- A* ---
# Path Exists: Yes
# Path: ['Fumigation', 'Herbicide', 'Vietnam War', 'France', 'Greece', '2011', 'Minecraft']
# Path Length: 7
# Runtime: 17.085090160369873
# Number of Nodes Visited: 191
# --- IDFS ---
# Path Exists: Yes
# Path: ['Fumigation', 'Herbicide', 'Vietnam War', 'France', 'Greece', '2011', 'Minecraft']
# Path Length: 7
# Runtime: 0.34005236625671387
# Number of Nodes Visited: 29510
#
#
# 33
# --- Run 33 with Starting Article: Eleazar of Worms ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Eleazar of Worms', 'Judaism', 'Earth', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.16954517364501953
# Number of Nodes Visited: 39093
# --- A* ---
# Path Exists: Yes
# Path: ['Eleazar of Worms', 'France', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 26.662431240081787
# Number of Nodes Visited: 366
# --- IDFS ---
# Path Exists: Yes
# Path: ['Eleazar of Worms', 'Judaism', 'Earth', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.10766768455505371
# Number of Nodes Visited: 10409
#
#
# 34
# --- Run 34 with Starting Article: National Football League ---
# --- BFS ---
# Path Exists: Yes
# Path: ['National Football League', 'Carolina Panthers', '1995', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.17113566398620605
# Number of Nodes Visited: 39650
# --- A* ---
# Path Exists: Yes
# Path: ['National Football League', 'Roger Goodell', 'August 8', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 6.339527368545532
# Number of Nodes Visited: 53
# --- IDFS ---
# Path Exists: Yes
# Path: ['National Football League', 'Carolina Panthers', '1995', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.08377599716186523
# Number of Nodes Visited: 6381
#
#
# 35
# --- Run 35 with Starting Article: Zaal Udumashvili ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Zaal Udumashvili', 'Georgia (country)', 'Turkey', 'Greece', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.1186826229095459
# Number of Nodes Visited: 21777
# --- A* ---
# Path Exists: Yes
# Path: ['Zaal Udumashvili', 'Georgia (country)', 'NATO', 'YouTube', 'PewDiePie', 'Minecraft']
# Path Length: 6
# Runtime: 8.344827890396118
# Number of Nodes Visited: 109
# --- IDFS ---
# Path Exists: Yes
# Path: ['Zaal Udumashvili', 'Georgia (country)', 'Turkey', 'Greece', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.06782364845275879
# Number of Nodes Visited: 5659
#
#
# 36
# --- Run 36 with Starting Article: Mehdi Tabatabaei ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Mehdi Tabatabaei', 'Mahmoud Ahmadinejad', 'Iran–Iraq War', 'September 22', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.7528469562530518
# Number of Nodes Visited: 24964
# --- A* ---
# Path Exists: Yes
# Path: ['Mehdi Tabatabaei', 'Iran', 'International Atomic Energy Agency', 'July 29', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 11.533949136734009
# Number of Nodes Visited: 102
# --- IDFS ---
# Path Exists: Yes
# Path: ['Mehdi Tabatabaei', 'Mahmoud Ahmadinejad', 'Iran–Iraq War', 'September 22', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.05947232246398926
# Number of Nodes Visited: 5576
#
#
# 37
# --- Run 37 with Starting Article: Engis ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Engis', 'Liège (province)', 'Luxembourg', 'September', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.18800830841064453
# Number of Nodes Visited: 44852
# --- A* ---
# Path Exists: Yes
# Path: ['Engis', 'Belgium', 'Belgian Grand Prix', '1925', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 15.762328386306763
# Number of Nodes Visited: 255
# --- IDFS ---
# Path Exists: Yes
# Path: ['Engis', 'Liège (province)', 'Luxembourg', 'September', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.1655595302581787
# Number of Nodes Visited: 16225
#
#
# 38
# --- Run 38 with Starting Article: Murder of Samuel Paty ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Murder of Samuel Paty', 'Facebook', 'Super Smash Bros.', 'Mario', 'Minecraft']
# Path Length: 5
# Runtime: 0.8334376811981201
# Number of Nodes Visited: 52987
# --- A* ---
# Path Exists: Yes
# Path: ['Murder of Samuel Paty', 'Emmanuel Macron', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 5.867506504058838
# Number of Nodes Visited: 42
# --- IDFS ---
# Path Exists: Yes
# Path: ['Murder of Samuel Paty', 'Facebook', 'Super Smash Bros.', 'Mario', 'Minecraft']
# Path Length: 5
# Runtime: 0.1474912166595459
# Number of Nodes Visited: 12153
#
#
# 39
# --- Run 39 with Starting Article: Frank Farrar ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Frank Farrar', 'Republican Party (United States)', '20th century', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.7719528675079346
# Number of Nodes Visited: 23347
# --- A* ---
# Path Exists: Yes
# Path: ['Frank Farrar', 'South Dakota', 'Coyote', 'Wolf', 'Minecraft']
# Path Length: 5
# Runtime: 9.502772331237793
# Number of Nodes Visited: 100
# --- IDFS ---
# Path Exists: Yes
# Path: ['Frank Farrar', 'Republican Party (United States)', '20th century', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.05086398124694824
# Number of Nodes Visited: 4723
#
#
# 40
# --- Run 40 with Starting Article: Laura Wissink ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Laura Wissink', 'Enschede', '2000', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.15541720390319824
# Number of Nodes Visited: 33140
# --- A* ---
# Path Exists: Yes
# Path: ['Laura Wissink', 'Enschede', '2000', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 12.66471815109253
# Number of Nodes Visited: 90
# --- IDFS ---
# Path Exists: Yes
# Path: ['Laura Wissink', 'Enschede', '2000', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.06981325149536133
# Number of Nodes Visited: 6772
#
#
# 41
# --- Run 41 with Starting Article: Sarangthem ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Sarangthem', 'India', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.74118971824646
# Number of Nodes Visited: 20474
# --- A* ---
# Path Exists: Yes
# Path: ['Sarangthem', 'India', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 7.547178745269775
# Number of Nodes Visited: 114
# --- IDFS ---
# Path Exists: Yes
# Path: ['Sarangthem', 'India', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.044879913330078125
# Number of Nodes Visited: 4697
#
#
# 42
# --- Run 42 with Starting Article: Ghulam Khan ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Ghulam Khan', 'Afghanistan', 'Islam', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 0.16057085990905762
# Number of Nodes Visited: 35682
# --- A* ---
# Path Exists: Yes
# Path: ['Ghulam Khan', 'Pakistan', 'Sri Lanka', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 17.287190437316895
# Number of Nodes Visited: 396
# --- IDFS ---
# Path Exists: Yes
# Path: ['Ghulam Khan', 'Afghanistan', 'Islam', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 0.16455984115600586
# Number of Nodes Visited: 17073
#
#
# 43
# --- Run 43 with Starting Article: UEFA Women's Euro 2013 ---
# --- BFS ---
# Path Exists: Yes
# Path: ["UEFA Women's Euro 2013", 'Italy', '2022', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.8627183437347412
# Number of Nodes Visited: 53820
# --- A* ---
# Path Exists: Yes
# Path: ["UEFA Women's Euro 2013", 'Finland', 'Nokia, Finland', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 9.086461305618286
# Number of Nodes Visited: 131
# --- IDFS ---
# Path Exists: Yes
# Path: ["UEFA Women's Euro 2013", 'Italy', '2022', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.1326451301574707
# Number of Nodes Visited: 10971
#
#
# 44
# --- Run 44 with Starting Article: Serbia ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Serbia', 'Albanian language', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.12267208099365234
# Number of Nodes Visited: 23505
# --- A* ---
# Path Exists: Yes
# Path: ['Serbia', 'Balkans', '2000', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 6.91255259513855
# Number of Nodes Visited: 59
# --- IDFS ---
# Path Exists: Yes
# Path: ['Serbia', 'Albanian language', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.05185985565185547
# Number of Nodes Visited: 4877
#
#
# 45
# --- Run 45 with Starting Article: Vickers Valiant ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Vickers Valiant', 'Royal Air Force', 'Cyprus', 'Greece', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.22436761856079102
# Number of Nodes Visited: 63094
# --- A* ---
# Path Exists: Yes
# Path: ['Vickers Valiant', 'Cold War', 'Moscow', 'Pyongyang', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 24.6125226020813
# Number of Nodes Visited: 323
# --- IDFS ---
# Path Exists: Yes
# Path: ['Vickers Valiant', 'Royal Air Force', 'Cyprus', 'Greece', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.38496971130371094
# Number of Nodes Visited: 33615
#
#
# 46
# --- Run 46 with Starting Article: Gurbrü ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Gurbrü', 'Cantons of Switzerland', '2001', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.7581865787506104
# Number of Nodes Visited: 23688
# --- A* ---
# Path Exists: Yes
# Path: ['Gurbrü', 'Cantons of Switzerland', '2001', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 6.965346813201904
# Number of Nodes Visited: 44
# --- IDFS ---
# Path Exists: Yes
# Path: ['Gurbrü', 'Cantons of Switzerland', '2001', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.03290557861328125
# Number of Nodes Visited: 2310
#
#
# 47
# --- Run 47 with Starting Article: Zarma language ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Zarma language', 'Niger', 'Unitary state', 'Greece', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.16755127906799316
# Number of Nodes Visited: 39140
# --- A* ---
# Path Exists: Yes
# Path: ['Zarma language', 'Niger', 'Niger River', 'September', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 14.21471643447876
# Number of Nodes Visited: 204
# --- IDFS ---
# Path Exists: Yes
# Path: ['Zarma language', 'Niger', 'Unitary state', 'Greece', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.17054343223571777
# Number of Nodes Visited: 16537
#
#
# 48
# --- Run 48 with Starting Article: Hanamachi ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Hanamachi', 'Japan', 'Nintendo', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.6632266044616699
# Number of Nodes Visited: 5699
# --- A* ---
# Path Exists: Yes
# Path: ['Hanamachi', 'Japan', 'Nintendo', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 11.873565196990967
# Number of Nodes Visited: 146
# --- IDFS ---
# Path Exists: Yes
# Path: ['Hanamachi', 'Japan', 'Nintendo', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.002991914749145508
# Number of Nodes Visited: 426
#
#
# 49
# --- Run 49 with Starting Article: Heinola ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Heinola', 'Finland', 'Nokia, Finland', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.0949091911315918
# Number of Nodes Visited: 14935
# --- A* ---
# Path Exists: Yes
# Path: ['Heinola', 'Finland', 'Nokia, Finland', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 1.9894084930419922
# Number of Nodes Visited: 38
# --- IDFS ---
# Path Exists: Yes
# Path: ['Heinola', 'Finland', 'Nokia, Finland', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.018947839736938477
# Number of Nodes Visited: 1964
#
#
# 50
# --- Run 50 with Starting Article: Western grebe ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Western grebe', 'Grebe', 'Species', 'Wolf', 'Minecraft']
# Path Length: 5
# Runtime: 0.018917322158813477
# Number of Nodes Visited: 3115
# --- A* ---
# Path Exists: Yes
# Path: ['Western grebe', 'Grebe', 'Species', 'Wolf', 'Minecraft']
# Path Length: 5
# Runtime: 0.5302548408508301
# Number of Nodes Visited: 6
# --- IDFS ---
# Path Exists: Yes
# Path: ['Western grebe', 'Grebe', 'Species', 'Wolf', 'Minecraft']
# Path Length: 5
# Runtime: 0.0019943714141845703
# Number of Nodes Visited: 136
#
#
# 51
# --- Run 51 with Starting Article: Ger, Pyrénées-Atlantiques ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Ger, Pyrénées-Atlantiques', 'France', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.8130159378051758
# Number of Nodes Visited: 45746
# --- A* ---
# Path Exists: Yes
# Path: ['Ger, Pyrénées-Atlantiques', 'France', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 3.276474714279175
# Number of Nodes Visited: 11
# --- IDFS ---
# Path Exists: Yes
# Path: ['Ger, Pyrénées-Atlantiques', 'France', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.08974218368530273
# Number of Nodes Visited: 8482
#
#
# 52
# --- Run 52 with Starting Article: DC Extended Universe ---
# --- BFS ---
# Path Exists: Yes
# Path: ['DC Extended Universe', 'S', 'September', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.15156292915344238
# Number of Nodes Visited: 30378
# --- A* ---
# Path Exists: Yes
# Path: ['DC Extended Universe', 'Ben Affleck', 'MSN', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 11.072632074356079
# Number of Nodes Visited: 192
# --- IDFS ---
# Path Exists: Yes
# Path: ['DC Extended Universe', 'S', 'September', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.057845115661621094
# Number of Nodes Visited: 6192
#
#
# 53
# --- Run 53 with Starting Article: West Columbia, Texas ---
# --- BFS ---
# Path Exists: Yes
# Path: ['West Columbia, Texas', 'Houston', 'United States', 'Xbox Game Studios', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 0.8487656116485596
# Number of Nodes Visited: 52805
# --- A* ---
# Path Exists: Yes
# Path: ['West Columbia, Texas', 'Texas', 'California', 'Technology company', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 10.319884061813354
# Number of Nodes Visited: 102
# --- IDFS ---
# Path Exists: Yes
# Path: ['West Columbia, Texas', 'Houston', 'United States', 'Xbox Game Studios', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 0.4418184757232666
# Number of Nodes Visited: 42880
#
#
# 54
# --- Run 54 with Starting Article: Malcolm E. Beard ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Malcolm E. Beard', 'Republican Party (United States)', '20th century', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.12303948402404785
# Number of Nodes Visited: 20245
# --- A* ---
# Path Exists: Yes
# Path: ['Malcolm E. Beard', 'Republican Party (United States)', '20th century', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 16.561769247055054
# Number of Nodes Visited: 204
# --- IDFS ---
# Path Exists: Yes
# Path: ['Malcolm E. Beard', 'Republican Party (United States)', '20th century', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.03989434242248535
# Number of Nodes Visited: 3470
#
#
# 55
# --- Run 55 with Starting Article: Federal Ministry for Economic Cooperation and Development ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Federal Ministry for Economic Cooperation and Development', '1961', 'December 20', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.20644450187683105
# Number of Nodes Visited: 52548
# --- A* ---
# Path Exists: Yes
# Path: ['Federal Ministry for Economic Cooperation and Development', '1993', 'December 16', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 6.37565803527832
# Number of Nodes Visited: 27
# --- IDFS ---
# Path Exists: Yes
# Path: ['Federal Ministry for Economic Cooperation and Development', '1961', 'December 20', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.13861918449401855
# Number of Nodes Visited: 11132
#
#
# 56
# --- Run 56 with Starting Article: Mongolia ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Mongolia', 'East Asia', 'Pyongyang', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.7679433822631836
# Number of Nodes Visited: 26177
# --- A* ---
# Path Exists: Yes
# Path: ['Mongolia', 'North Korea', 'Pyongyang', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 16.483087062835693
# Number of Nodes Visited: 223
# --- IDFS ---
# Path Exists: Yes
# Path: ['Mongolia', 'East Asia', 'Pyongyang', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.08278465270996094
# Number of Nodes Visited: 8464
#
#
# 57
# 58
# --- Run 58 with Starting Article: Panevėžys ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Panevėžys', 'County', '1989', 'PewDiePie', 'Minecraft']
# Path Length: 5
# Runtime: 0.0980377197265625
# Number of Nodes Visited: 16531
# --- A* ---
# Path Exists: Yes
# Path: ['Panevėžys', 'County', '1989', 'PewDiePie', 'Minecraft']
# Path Length: 5
# Runtime: 8.100889921188354
# Number of Nodes Visited: 52
# --- IDFS ---
# Path Exists: Yes
# Path: ['Panevėžys', 'County', '1989', 'PewDiePie', 'Minecraft']
# Path Length: 5
# Runtime: 0.011962652206420898
# Number of Nodes Visited: 602
#
#
# 59
# --- Run 59 with Starting Article: Puravadayanar River ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Puravadayanar River', 'Karaikal district', 'List of districts of India', 'Firozabad district', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.7195558547973633
# Number of Nodes Visited: 14663
# --- A* ---
# Path Exists: Yes
# Path: ['Puravadayanar River', 'Bay of Bengal', 'India', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 10.29375410079956
# Number of Nodes Visited: 260
# --- IDFS ---
# Path Exists: Yes
# Path: ['Puravadayanar River', 'Karaikal district', 'List of districts of India', 'Firozabad district', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.02094435691833496
# Number of Nodes Visited: 2534
#
#
# 60
# --- Run 60 with Starting Article: Communist Party of the Soviet Union ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Communist Party of the Soviet Union', 'World War I', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.11967849731445312
# Number of Nodes Visited: 21716
# --- A* ---
# Path Exists: Yes
# Path: ['Communist Party of the Soviet Union', 'Moscow', 'Earth', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 5.484535455703735
# Number of Nodes Visited: 51
# --- IDFS ---
# Path Exists: Yes
# Path: ['Communist Party of the Soviet Union', 'World War I', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.041887760162353516
# Number of Nodes Visited: 3718
#
#
# 61
# --- Run 61 with Starting Article: Lateef Raji ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Lateef Raji', 'Strategy', 'Carl von Clausewitz', 'November 16', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.12768983840942383
# Number of Nodes Visited: 24469
# --- A* ---
# Path Exists: Yes
# Path: ['Lateef Raji', 'Lagos', 'Atlantic Ocean', 'Earth', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 12.819862365722656
# Number of Nodes Visited: 208
# --- IDFS ---
# Path Exists: Yes
# Path: ['Lateef Raji', 'Strategy', 'Carl von Clausewitz', 'November 16', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.038895606994628906
# Number of Nodes Visited: 3549
#
#
# 62
# --- Run 62 with Starting Article: Rio Tinto ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Rio Tinto', 'Melbourne', '2006', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.6971359252929688
# Number of Nodes Visited: 11812
# --- A* ---
# Path Exists: Yes
# Path: ['Rio Tinto', 'Australia', 'Royal Australian Navy', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 4.291390419006348
# Number of Nodes Visited: 28
# --- IDFS ---
# Path Exists: Yes
# Path: ['Rio Tinto', 'Melbourne', '2006', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.007978677749633789
# Number of Nodes Visited: 590
#
#
# 63
# --- Run 63 with Starting Article: L'Île-d'Olonne ---
# --- BFS ---
# Path Exists: Yes
# Path: ["L'Île-d'Olonne", 'France', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.17552924156188965
# Number of Nodes Visited: 45759
# --- A* ---
# Path Exists: Yes
# Path: ["L'Île-d'Olonne", 'France', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 6.462156772613525
# Number of Nodes Visited: 68
# --- IDFS ---
# Path Exists: Yes
# Path: ["L'Île-d'Olonne", 'France', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.08178043365478516
# Number of Nodes Visited: 6688
#
#
# 64
# --- Run 64 with Starting Article: Robert William Fisher ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Robert William Fisher', 'Federal Bureau of Investigation', 'United States', 'Xbox Game Studios', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 0.826758623123169
# Number of Nodes Visited: 48773
# --- A* ---
# Path Exists: Yes
# Path: ['Robert William Fisher', 'Americans', 'Mexico', '1910', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 26.542479991912842
# Number of Nodes Visited: 315
# --- IDFS ---
# Path Exists: Yes
# Path: ['Robert William Fisher', 'Federal Bureau of Investigation', 'United States', 'Xbox Game Studios', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 0.17752480506896973
# Number of Nodes Visited: 16702
#
#
# 65
# 66
# --- Run 66 with Starting Article: Pedro José de Arteta ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Pedro José de Arteta', 'Quito', '2020', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.15857601165771484
# Number of Nodes Visited: 37076
# --- A* ---
# Path Exists: Yes
# Path: ['Pedro José de Arteta', 'Quito', '2020', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 7.192826271057129
# Number of Nodes Visited: 10
# --- IDFS ---
# Path Exists: Yes
# Path: ['Pedro José de Arteta', 'Quito', '2020', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.05384516716003418
# Number of Nodes Visited: 4121
#
#
# 67
# --- Run 67 with Starting Article: Bredevoort Castle ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Bredevoort Castle', '1646', 'February 16', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.7813625335693359
# Number of Nodes Visited: 31235
# --- A* ---
# Path Exists: Yes
# Path: ['Bredevoort Castle', '1646', 'December 21', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 4.180319786071777
# Number of Nodes Visited: 11
# --- IDFS ---
# Path Exists: Yes
# Path: ['Bredevoort Castle', '1646', 'February 16', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.06083965301513672
# Number of Nodes Visited: 6023
#
#
# 68
# --- Run 68 with Starting Article: Pergine Valdarno ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Pergine Valdarno', 'Italy', '2022', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.14959979057312012
# Number of Nodes Visited: 34695
# --- A* ---
# Path Exists: Yes
# Path: ['Pergine Valdarno', 'Tuscany', '1995', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 9.508174896240234
# Number of Nodes Visited: 98
# --- IDFS ---
# Path Exists: Yes
# Path: ['Pergine Valdarno', 'Italy', '2022', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.037897586822509766
# Number of Nodes Visited: 2294
#
#
# 69
# --- Run 69 with Starting Article: Étouvelles ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Étouvelles', 'France', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.8030219078063965
# Number of Nodes Visited: 35192
# --- A* ---
# Path Exists: Yes
# Path: ['Étouvelles', 'Departments of France', 'Guéret', 'Wolf', 'Minecraft']
# Path Length: 5
# Runtime: 8.144863843917847
# Number of Nodes Visited: 79
# --- IDFS ---
# Path Exists: Yes
# Path: ['Étouvelles', 'France', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.08477282524108887
# Number of Nodes Visited: 8307
#
#
# 70
# --- Run 70 with Starting Article: National Archaeological Museum, Naples ---
# --- BFS ---
# Path Exists: Yes
# Path: ['National Archaeological Museum, Naples', 'Italy', '2022', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.15259194374084473
# Number of Nodes Visited: 35035
# --- A* ---
# Path Exists: Yes
# Path: ['National Archaeological Museum, Naples', 'Italy', '2022', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 9.65455174446106
# Number of Nodes Visited: 13
# --- IDFS ---
# Path Exists: Yes
# Path: ['National Archaeological Museum, Naples', 'Italy', '2022', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.03699755668640137
# Number of Nodes Visited: 2091
#
#
# 71
# --- Run 71 with Starting Article: Kuttimannilbethel ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Kuttimannilbethel', 'List of districts of India', 'Firozabad district', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.7778506278991699
# Number of Nodes Visited: 28219
# --- A* ---
# Path Exists: Yes
# Path: ['Kuttimannilbethel', 'India', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 3.947518825531006
# Number of Nodes Visited: 58
# --- IDFS ---
# Path Exists: Yes
# Path: ['Kuttimannilbethel', 'List of districts of India', 'Firozabad district', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.06781840324401855
# Number of Nodes Visited: 6805
#
#
# 72
# --- Run 72 with Starting Article: Samer Kamal ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Samer Kamal', 'Taekwondo', '1992', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.19547724723815918
# Number of Nodes Visited: 50516
# --- A* ---
# Path Exists: Yes
# Path: ['Samer Kamal', 'Aberdeen', '1910', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 9.69679856300354
# Number of Nodes Visited: 50
# --- IDFS ---
# Path Exists: Yes
# Path: ['Samer Kamal', 'Taekwondo', '1992', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.151594877243042
# Number of Nodes Visited: 13652
#
#
# 73
# --- Run 73 with Starting Article: Dog Day Afternoon ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Dog Day Afternoon', 'Box Office Mojo', '1999', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.8239288330078125
# Number of Nodes Visited: 41145
# --- A* ---
# Path Exists: Yes
# Path: ['Dog Day Afternoon', 'Academy Award for Best Actor', 'Steve Jobs', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 14.560637474060059
# Number of Nodes Visited: 198
# --- IDFS ---
# Path Exists: Yes
# Path: ['Dog Day Afternoon', 'Box Office Mojo', '1999', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.10471940040588379
# Number of Nodes Visited: 9913
#
#
# 74
# --- Run 74 with Starting Article: Sweden, Maine ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Sweden, Maine', 'United States', 'Xbox Game Studios', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.17253899574279785
# Number of Nodes Visited: 39699
# --- A* ---
# Path Exists: Yes
# Path: ['Sweden, Maine', 'United States', 'Xbox Game Studios', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 10.013741731643677
# Number of Nodes Visited: 106
# --- IDFS ---
# Path Exists: Yes
# Path: ['Sweden, Maine', 'United States', 'Xbox Game Studios', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.10580778121948242
# Number of Nodes Visited: 9948
#
#
# 75
# --- Run 75 with Starting Article: Roberto Alcaide García ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Roberto Alcaide García', 'Madrid', '1980', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.17205190658569336
# Number of Nodes Visited: 41884
# --- A* ---
# Path Exists: Yes
# Path: ['Roberto Alcaide García', 'Madrid', '1980', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 13.433845281600952
# Number of Nodes Visited: 99
# --- IDFS ---
# Path Exists: Yes
# Path: ['Roberto Alcaide García', 'Madrid', '1980', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.07782220840454102
# Number of Nodes Visited: 2643
#
#
# 76
# --- Run 76 with Starting Article: Reichskommissariat Ostland ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Reichskommissariat Ostland', 'Judaism', 'Earth', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.12073326110839844
# Number of Nodes Visited: 21173
# --- A* ---
# Path Exists: Yes
# Path: ['Reichskommissariat Ostland', 'World War II', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 13.154435873031616
# Number of Nodes Visited: 167
# --- IDFS ---
# Path Exists: Yes
# Path: ['Reichskommissariat Ostland', 'Judaism', 'Earth', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.04188799858093262
# Number of Nodes Visited: 3778
#
#
# 77
# 78
# --- Run 78 with Starting Article: 2010 Africa Cup of Nations ---
# --- BFS ---
# Path Exists: Yes
# Path: ['2010 Africa Cup of Nations', 'Gabon national football team', 'Rabat', 'Greece', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.18737149238586426
# Number of Nodes Visited: 45592
# --- A* ---
# Path Exists: Yes
# Path: ['2010 Africa Cup of Nations', 'Luanda', '1975', '1921', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 17.711104154586792
# Number of Nodes Visited: 303
# --- IDFS ---
# Path Exists: Yes
# Path: ['2010 Africa Cup of Nations', 'Gabon national football team', 'Rabat', 'Greece', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.19148969650268555
# Number of Nodes Visited: 18110
#
#
# 79
# --- Run 79 with Starting Article: The Black Stallion (movie) ---
# --- BFS ---
# Path Exists: Yes
# Path: ['The Black Stallion (movie)', 'Alexander the Great', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.7120475769042969
# Number of Nodes Visited: 15415
# --- A* ---
# Path Exists: Yes
# Path: ['The Black Stallion (movie)', 'Academy Award for Best Supporting Actor', 'Gary Sinise', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 8.794616222381592
# Number of Nodes Visited: 94
# --- IDFS ---
# Path Exists: Yes
# Path: ['The Black Stallion (movie)', 'Alexander the Great', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.015958309173583984
# Number of Nodes Visited: 1759
#
#
# 80
# --- Run 80 with Starting Article: God of War III ---
# --- BFS ---
# Path Exists: Yes
# Path: ['God of War III', 'PlayStation 3', 'PlayStation 4', 'Minecraft']
# Path Length: 4
# Runtime: 0.006977558135986328
# Number of Nodes Visited: 1045
# --- A* ---
# Path Exists: Yes
# Path: ['God of War III', 'PlayStation 3', 'Microsoft', 'Minecraft']
# Path Length: 4
# Runtime: 0.35604190826416016
# Number of Nodes Visited: 5
# --- IDFS ---
# Path Exists: Yes
# Path: ['God of War III', 'PlayStation 3', 'PlayStation 4', 'Minecraft']
# Path Length: 4
# Runtime: 0.0009970664978027344
# Number of Nodes Visited: 64
#
#
# 81
# --- Run 81 with Starting Article: Addis Ababa–Djibouti Railway ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Addis Ababa–Djibouti Railway', 'Djibouti', 'North America', 'Earth', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 0.1406242847442627
# Number of Nodes Visited: 29995
# --- A* ---
# Path Exists: Yes
# Path: ['Addis Ababa–Djibouti Railway', 'Ethiopia', 'League of Nations', '1940', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 13.952531814575195
# Number of Nodes Visited: 157
# --- IDFS ---
# Path Exists: Yes
# Path: ['Addis Ababa–Djibouti Railway', 'Djibouti', 'North America', 'Earth', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 0.08975982666015625
# Number of Nodes Visited: 8570
#
#
# 82
# --- Run 82 with Starting Article: Southampton Central railway station ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Southampton Central railway station', 'Southampton', 'United Kingdom', 'Species', 'Wolf', 'Minecraft']
# Path Length: 6
# Runtime: 0.774752140045166
# Number of Nodes Visited: 34818
# --- A* ---
# Path Exists: Yes
# Path: ['Southampton Central railway station', 'Southampton', 'United Kingdom', 'Species', 'Wolf', 'Minecraft']
# Path Length: 6
# Runtime: 12.207406282424927
# Number of Nodes Visited: 240
# --- IDFS ---
# Path Exists: Yes
# Path: ['Southampton Central railway station', 'Southampton', 'United Kingdom', 'Species', 'Wolf', 'Minecraft']
# Path Length: 6
# Runtime: 0.13962602615356445
# Number of Nodes Visited: 12983
#
#
# 83
# --- Run 83 with Starting Article: Red Jacket ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Red Jacket', 'United States', 'Xbox Game Studios', 'Microsoft', 'Minecraft']
# Path Length: 5
# ...
# --- BFS ---
# Path Exists: Yes
# Path: ['Shoaling and schooling', 'Defence against predators', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.7613270282745361
# Number of Nodes Visited: 22808
# --- A* ---
# Path Exists: Yes
# Path: ['Shoaling and schooling', 'Defence against predators', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 8.055004358291626
# Number of Nodes Visited: 79
# --- IDFS ---
# Path Exists: Yes
# Path: ['Shoaling and schooling', 'Defence against predators', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.035902976989746094
# Number of Nodes Visited: 3895
#
#
# 977
# --- Run 977 with Starting Article: Ewood Park ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Ewood Park', 'England', 'University of Cambridge', 'October', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.18048524856567383
# Number of Nodes Visited: 35447
# --- A* ---
# Path Exists: Yes
# Path: ['Ewood Park', 'England', 'United Kingdom', 'Species', 'Wolf', 'Minecraft']
# Path Length: 6
# Runtime: 20.920939207077026
# Number of Nodes Visited: 354
# --- IDFS ---
# Path Exists: Yes
# Path: ['Ewood Park', 'England', 'University of Cambridge', 'October', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.08477592468261719
# Number of Nodes Visited: 8097
#
#
# 978
# --- Run 978 with Starting Article: Rottenbach (river) ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Rottenbach (river)', 'Germany', 'Berlin Wall', '1989', 'PewDiePie', 'Minecraft']
# Path Length: 6
# Runtime: 0.8277506828308105
# Number of Nodes Visited: 42481
# --- A* ---
# Path Exists: Yes
# Path: ['Rottenbach (river)', 'Germany', 'Homelessness', 'YouTube', 'PewDiePie', 'Minecraft']
# Path Length: 6
# Runtime: 24.187843084335327
# Number of Nodes Visited: 418
# --- IDFS ---
# Path Exists: Yes
# Path: ['Rottenbach (river)', 'Germany', 'Berlin Wall', '1989', 'PewDiePie', 'Minecraft']
# Path Length: 6
# Runtime: 0.10568594932556152
# Number of Nodes Visited: 9536
#
#
# 979
# --- Run 979 with Starting Article: Pico Rivera, California ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Pico Rivera, California', 'World War II', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.16356182098388672
# Number of Nodes Visited: 36480
# --- A* ---
# Path Exists: Yes
# Path: ['Pico Rivera, California', 'Los Angeles County, California', 'Activision Blizzard', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 8.140810012817383
# Number of Nodes Visited: 71
# --- IDFS ---
# Path Exists: Yes
# Path: ['Pico Rivera, California', 'World War II', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.09174656867980957
# Number of Nodes Visited: 7915
#
#
# 980
# --- Run 980 with Starting Article: Tentaculata ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Tentaculata', 'Animal', 'Earth', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.03986024856567383
# Number of Nodes Visited: 6770
# --- A* ---
# Path Exists: Yes
# Path: ['Tentaculata', 'Animal', 'Earth', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 1.5228700637817383
# Number of Nodes Visited: 27
# --- IDFS ---
# Path Exists: Yes
# Path: ['Tentaculata', 'Animal', 'Earth', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.004987001419067383
# Number of Nodes Visited: 908
#
#
# 981
# --- Run 981 with Starting Article: Noppenspitze ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Noppenspitze', 'Allgäu Alps', 'Glacier', 'July 26', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.8382325172424316
# Number of Nodes Visited: 43899
# --- A* ---
# Path Exists: Yes
# Path: ['Noppenspitze', 'Dolomite', 'Italy', '2022', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 12.372237205505371
# Number of Nodes Visited: 53
# --- IDFS ---
# Path Exists: Yes
# Path: ['Noppenspitze', 'Allgäu Alps', 'Glacier', 'July 26', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.364013671875
# Number of Nodes Visited: 34586
#
#
# 982
# --- Run 982 with Starting Article: Mountain Dew ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Mountain Dew', 'Orange (color)', 'Autumn', 'September', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.16057276725769043
# Number of Nodes Visited: 32474
# --- A* ---
# Path Exists: Yes
# Path: ['Mountain Dew', 'Taco Bell', 'United States', 'Xbox Game Studios', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 15.665517807006836
# Number of Nodes Visited: 220
# --- IDFS ---
# Path Exists: Yes
# Path: ['Mountain Dew', 'Orange (color)', 'Autumn', 'September', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.08178520202636719
# Number of Nodes Visited: 8277
#
#
# 983
# --- Run 983 with Starting Article: Lieutenancies Act 1997 ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Lieutenancies Act 1997', 'Act of Parliament', 'Portugal', '1910', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.7437233924865723
# Number of Nodes Visited: 17892
# --- A* ---
# Path Exists: Yes
# Path: ['Lieutenancies Act 1997', 'Act of Parliament', 'Portugal', '1910', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 14.73156213760376
# Number of Nodes Visited: 175
# --- IDFS ---
# Path Exists: Yes
# Path: ['Lieutenancies Act 1997', 'Act of Parliament', 'Portugal', '1910', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.024966001510620117
# Number of Nodes Visited: 2659
#
#
# 984
# --- Run 984 with Starting Article: Pope Adeodatus I ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Pope Adeodatus I', 'Byzantine Empire', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.11368751525878906
# Number of Nodes Visited: 19832
# --- A* ---
# Path Exists: Yes
# Path: ['Pope Adeodatus I', 'Byzantine Empire', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 6.623211622238159
# Number of Nodes Visited: 49
# --- IDFS ---
# Path Exists: Yes
# Path: ['Pope Adeodatus I', 'Byzantine Empire', 'Greece', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.03194570541381836
# Number of Nodes Visited: 3188
#
#
# 985
# --- Run 985 with Starting Article: International Bureau of Weights and Measures ---
# --- BFS ---
# Path Exists: Yes
# Path: ['International Bureau of Weights and Measures', 'Scientist', 'Rock (geology)', 'Earth', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 0.11767935752868652
# Number of Nodes Visited: 24086
# --- A* ---
# Path Exists: Yes
# Path: ['International Bureau of Weights and Measures', 'Scientist', 'Rock (geology)', 'Earth', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 4.8618340492248535
# Number of Nodes Visited: 71
# --- IDFS ---
# Path Exists: Yes
# Path: ['International Bureau of Weights and Measures', 'Scientist', 'Rock (geology)', 'Earth', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 0.044847726821899414
# Number of Nodes Visited: 6550
#
#
# 986
# --- Run 986 with Starting Article: List of German monarchs ---
# --- BFS ---
# Path Exists: Yes
# Path: ['List of German monarchs', 'Franz Joseph I of Austria', '1916', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.7500262260437012
# Number of Nodes Visited: 18871
# --- A* ---
# Path Exists: Yes
# Path: ['List of German monarchs', 'Franz Joseph I of Austria', '1916', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 7.443094491958618
# Number of Nodes Visited: 92
# --- IDFS ---
# Path Exists: Yes
# Path: ['List of German monarchs', 'Franz Joseph I of Austria', '1916', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.037899017333984375
# Number of Nodes Visited: 3249
#
#
# 987
# --- Run 987 with Starting Article: UTC+03:30 ---
# --- BFS ---
# Path Exists: Yes
# Path: ['UTC+03:30', 'Iran', 'Ancient Greece', 'Greece', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.17855238914489746
# Number of Nodes Visited: 38326
# --- A* ---
# Path Exists: Yes
# Path: ['UTC+03:30', 'Iran', 'Iran–Iraq War', 'September 22', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 9.869965076446533
# Number of Nodes Visited: 94
# --- IDFS ---
# Path Exists: Yes
# Path: ['UTC+03:30', 'Iran', 'Ancient Greece', 'Greece', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.0887458324432373
# Number of Nodes Visited: 7297
#
#
# 988
# --- Run 988 with Starting Article: Juan Ayala ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Juan Ayala', 'Paraguay national football team', 'Hong Kong', 'National emblem', 'Wolf', 'Minecraft']
# Path Length: 6
# Runtime: 0.8058450222015381
# Number of Nodes Visited: 35052
# --- A* ---
# Path Exists: Yes
# Path: ['Juan Ayala', 'Paraguay national football team', '2004 Summer Olympics', 'Greece', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 15.457799196243286
# Number of Nodes Visited: 124
# --- IDFS ---
# Path Exists: Yes
# Path: ['Juan Ayala', 'Paraguay national football team', 'Hong Kong', 'National emblem', 'Wolf', 'Minecraft']
# Path Length: 6
# Runtime: 0.04990196228027344
# Number of Nodes Visited: 2956
#
#
# 989
# --- Run 989 with Starting Article: Kinya Takehara ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Kinya Takehara', 'Japan', 'Nintendo', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.05482172966003418
# Number of Nodes Visited: 7518
# --- A* ---
# Path Exists: Yes
# Path: ['Kinya Takehara', 'Japan', 'Nintendo', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 12.29300856590271
# Number of Nodes Visited: 123
# --- IDFS ---
# Path Exists: Yes
# Path: ['Kinya Takehara', 'Japan', 'Nintendo', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.0049877166748046875
# Number of Nodes Visited: 487
#
#
# 990
# --- Run 990 with Starting Article: Al-Ma'mun ---
# --- BFS ---
# Path Exists: Yes
# Path: ["Al-Ma'mun", 'Islam', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.12067604064941406
# Number of Nodes Visited: 22591
# --- A* ---
# Path Exists: Yes
# Path: ["Al-Ma'mun", 'Islam', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 8.911997318267822
# Number of Nodes Visited: 100
# --- IDFS ---
# Path Exists: Yes
# Path: ["Al-Ma'mun", 'Islam', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.05585169792175293
# Number of Nodes Visited: 6138
#
#
# 991
# --- Run 991 with Starting Article: Livermore, Maine ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Livermore, Maine', 'United States', 'Xbox Game Studios', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.8048427104949951
# Number of Nodes Visited: 39700
# --- A* ---
# Path Exists: Yes
# Path: ['Livermore, Maine', 'Maine', 'Moose', 'Wolf', 'Minecraft']
# Path Length: 5
# Runtime: 3.5275564193725586
# Number of Nodes Visited: 34
# --- IDFS ---
# Path Exists: Yes
# Path: ['Livermore, Maine', 'United States', 'Xbox Game Studios', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.10272836685180664
# Number of Nodes Visited: 9946
#
#
# 992
# --- Run 992 with Starting Article: Japanese Sign Language ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Japanese Sign Language', 'Japan', 'Nintendo', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.04687094688415527
# Number of Nodes Visited: 5708
# --- A* ---
# Path Exists: Yes
# Path: ['Japanese Sign Language', 'Japan', 'Nintendo', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 5.254360198974609
# Number of Nodes Visited: 49
# --- IDFS ---
# Path Exists: Yes
# Path: ['Japanese Sign Language', 'Japan', 'Nintendo', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.003983259201049805
# Number of Nodes Visited: 433
#
#
# 993
# --- Run 993 with Starting Article: Veronika Marchenko ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Veronika Marchenko', 'Russia', 'History of Russia', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 0.8855152130126953
# Number of Nodes Visited: 56650
# --- A* ---
# Path Exists: Yes
# Path: ['Veronika Marchenko', 'Russia', '1993', 'May 14', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 25.444490909576416
# Number of Nodes Visited: 347
# --- IDFS ---
# Path Exists: Yes
# Path: ['Veronika Marchenko', 'Russia', 'History of Russia', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 0.1934807300567627
# Number of Nodes Visited: 15579
#
#
# 994
# --- Run 994 with Starting Article: Yana Yagodina ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Yana Yagodina', 'Kazakhstan', 'Islam', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 0.14692473411560059
# Number of Nodes Visited: 32648
# --- A* ---
# Path Exists: Yes
# Path: ['Yana Yagodina', 'Kazakhstan', 'Official script', 'Document', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 7.393855810165405
# Number of Nodes Visited: 86
# --- IDFS ---
# Path Exists: Yes
# Path: ['Yana Yagodina', 'Kazakhstan', 'Islam', 'Encyclopædia Britannica', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 0.11867642402648926
# Number of Nodes Visited: 10192
#
#
# 995
# --- Run 995 with Starting Article: Bull (2016 TV series) ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Bull (2016 TV series)', 'United States', 'Xbox Game Studios', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.8656783103942871
# Number of Nodes Visited: 39755
# --- A* ---
# Path Exists: Yes
# Path: ['Bull (2016 TV series)', 'United States', 'Xbox Game Studios', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 8.386537075042725
# Number of Nodes Visited: 86
# --- IDFS ---
# Path Exists: Yes
# Path: ['Bull (2016 TV series)', 'United States', 'Xbox Game Studios', 'Microsoft', 'Minecraft']
# Path Length: 5
# Runtime: 0.10471749305725098
# Number of Nodes Visited: 10088
#
#
# 996
# --- Run 996 with Starting Article: David Trone ---
# --- BFS ---
# Path Exists: Yes
# Path: ['David Trone', 'Maryland', 'Baltimore', 'January', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.19380903244018555
# Number of Nodes Visited: 49106
# --- A* ---
# Path Exists: Yes
# Path: ['David Trone', 'Democratic Party (United States)', 'New Mexico', 'American black bear', 'Wolf', 'Minecraft']
# Path Length: 6
# Runtime: 27.48884391784668
# Number of Nodes Visited: 348
# --- IDFS ---
# Path Exists: Yes
# Path: ['David Trone', 'Maryland', 'Baltimore', 'January', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.20243334770202637
# Number of Nodes Visited: 18145
#
#
# 997
# --- Run 997 with Starting Article: Hajji Washington ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Hajji Washington', 'Ezzatolah Entezami', 'Actor', 'Greece', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.8267881870269775
# Number of Nodes Visited: 13919
# --- A* ---
# Path Exists: Yes
# Path: ['Hajji Washington', 'Ezzatolah Entezami', 'Actor', 'Greece', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 2.745659112930298
# Number of Nodes Visited: 8
# --- IDFS ---
# Path Exists: Yes
# Path: ['Hajji Washington', 'Ezzatolah Entezami', 'Actor', 'Greece', '2011', 'Minecraft']
# Path Length: 6
# Runtime: 0.012000799179077148
# Number of Nodes Visited: 1237
#
#
# 998
# --- Run 998 with Starting Article: Chōhō (era) ---
# --- BFS ---
# Path Exists: Yes
# Path: ['Chōhō (era)', 'National Diet Library', 'Japan', 'Nintendo', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 0.1435856819152832
# Number of Nodes Visited: 26105
# --- A* ---
# Path Exists: Yes
# Path: ['Chōhō (era)', 'Japanese era name', 'Gregorian calendar', 'Earth', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 4.92929744720459
# Number of Nodes Visited: 145
# --- IDFS ---
# Path Exists: Yes
# Path: ['Chōhō (era)', 'National Diet Library', 'Japan', 'Nintendo', 'Microsoft', 'Minecraft']
# Path Length: 6
# Runtime: 0.13463664054870605
# Number of Nodes Visited: 18463
#
#
# 999
# --- Run 999 with Starting Article: List of presidents of Equatorial Guinea ---
# --- BFS ---
# Path Exists: Yes
# Path: ['List of presidents of Equatorial Guinea', 'Teodoro Obiang Nguema Mbasogo', '1942', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.792884349822998
# Number of Nodes Visited: 31496
# --- A* ---
# Path Exists: Yes
# Path: ['List of presidents of Equatorial Guinea', 'Teodoro Obiang Nguema Mbasogo', 'June 5', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 5.027687072753906
# Number of Nodes Visited: 21
# --- IDFS ---
# Path Exists: Yes
# Path: ['List of presidents of Equatorial Guinea', 'Teodoro Obiang Nguema Mbasogo', '1942', '2011', 'Minecraft']
# Path Length: 5
# Runtime: 0.04686594009399414
# Number of Nodes Visited: 2611
#
#
# 1000
# --- Run 1000 with Starting Article: Jack-o'-lantern ---
# --- BFS ---
# Path Exists: Yes
# Path: ["Jack-o'-lantern", '20th century', '2011', 'Minecraft']
# Path Length: 4
# Runtime: 0.05781364440917969
# Number of Nodes Visited: 4606
# --- A* ---
# Path Exists: Yes
# Path: ["Jack-o'-lantern", '20th century', '2011', 'Minecraft']
# Path Length: 4
# Runtime: 5.245612144470215
# Number of Nodes Visited: 8
# --- IDFS ---
# Path Exists: Yes
# Path: ["Jack-o'-lantern", '20th century', '2011', 'Minecraft']
# Path Length: 4
# Runtime: 0.001981496810913086
# Number of Nodes Visited: 285

# %%
# Tính kết quả trung bình
bfs_average_path_length = bfs_total_path_length / \
    bfs_path_exists_count if bfs_path_exists_count > 0 else 0
astar_average_path_length = astar_total_path_length / \
    astar_path_exists_count if astar_path_exists_count > 0 else 0
idfs_average_path_length = idfs_total_path_length / \
    idfs_path_exists_count if idfs_path_exists_count > 0 else 0
bfs_average_node_count = bfs_total_node_count / valid_runs
astar_average_node_count = astar_total_node_count / valid_runs
idfs_average_node_count = idfs_total_node_count / valid_runs
bfs_average_runtime = bfs_total_runtime / valid_runs if valid_runs > 0 else 0
astar_average_runtime = astar_total_runtime / valid_runs if valid_runs > 0 else 0
idfs_average_runtime = idfs_total_runtime / valid_runs if valid_runs > 0 else 0

# In thống kế
print("--- Overall Results ---")
print("Number of Runs:", run_count)
print("BFS Path Exists Count:", bfs_path_exists_count)
print("BFS Average Path Length:", bfs_average_path_length)
print("BFS Average Number of Nodes Visited:", bfs_average_node_count)
print("BFS Average Runtime:", bfs_average_runtime)
print("\n")
print("A* Path Exists Count:", astar_path_exists_count)
print("A* Average Path Length:", astar_average_path_length)
print("A* Average Number of Nodes Visited:", astar_average_node_count)
print("A* Average Runtime:", astar_average_runtime)
print("\n")
print("IDFS Path Exists Count:", idfs_path_exists_count)
print("IDFS Average Path Length:", idfs_average_path_length)
print("IDFS Average Number of Nodes Visited:", idfs_average_node_count)
print("IDFS Average Runtime:", idfs_average_runtime)
# Out:
# --- Overall Results ---
# Number of Runs: 1000
# BFS Path Exists Count: 960
# BFS Average Path Length: 5.227083333333334
# BFS Average Number of Nodes Visited: 28537.425
# BFS Average Runtime: 0.404468218733867
#
#
# A* Path Exists Count: 960
# A* Average Path Length: 5.227083333333334
# A* Average Number of Nodes Visited: 125.28854166666666
# A* Average Runtime: 11.181151875853539
#
#
# IDFS Path Exists Count: 960
# IDFS Average Path Length: 5.227083333333334
# IDFS Average Number of Nodes Visited: 7175.5125
# IDFS Average Runtime: 0.0791292463739713

# %%
# Create a bar plot for the number of runs
x = ["BFS", "A*", "IDFS"]
y = [bfs_path_exists_count, astar_path_exists_count, idfs_path_exists_count]
plt.bar(x, y)
plt.xlabel("Algorithm")
plt.ylabel("Path Exists Count")
plt.title("Number of Runs")
plt.show()

# Create a bar plot for the average path length
x = ["BFS", "A*", "IDFS"]
y = [bfs_average_path_length, astar_average_path_length, idfs_average_path_length]
plt.bar(x, y)
plt.xlabel("Algorithm")
plt.ylabel("Average Path Length")
plt.title("Average Path Length")
plt.show()

# Create a bar plot for the average number of nodes visited
x = ["BFS", "A*", "IDFS"]
y = [bfs_average_node_count, astar_average_node_count, idfs_average_node_count]
plt.bar(x, y)
plt.xlabel("Algorithm")
plt.ylabel("Average Number of Nodes Visited")
plt.title("Average Number of Nodes Visited")
plt.show()

# Create a bar plot for the average runtime
x = ["BFS", "A*", "IDFS"]
y = [bfs_average_runtime, astar_average_runtime, idfs_average_runtime]
plt.bar(x, y)
plt.xlabel("Algorithm")
plt.ylabel("Average Runtime")
plt.title("Average Runtime")
plt.show()
